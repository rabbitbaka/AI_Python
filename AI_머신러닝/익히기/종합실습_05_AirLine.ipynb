# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/airport2.png?raw=true" width=800 align="left"/>

# %% [markdown]
# # 실습 내용
#
# - 여러 알고리즘으로 만든 모델의 성능을 교차 검증을 통해 예측해 봅니다.
# - 성능이 좋을 것으로 예상되는 알고리즘으로 최적화된 성능의 모델을 만듭니다.
# - 튜닝된 모델의 성능을 평가합니다.

# %% [markdown]
# # 1.환경 준비
#
# - 기본 라이브러리와 대상 데이터를 가져와 이후 과정을 준비합니다.

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
path = 'https://raw.githubusercontent.com/jangrae/csv/master/airline_satisfaction_small.csv'
data = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해
#
# - 분석할 데이터를 충분히 이해할 수 있도록 다양한 탐색 과정을 수행합니다.

# %% [markdown]
# **데이터 설명**
#
# - id : 탑승자 고유 아이디
# - gender: 성별 (Female, Male)
# - customer_type: 고객 유형 (Loyal customer, disloyal customer)
# - age: 탑승자 나이
# - type_of_travel: 비행 목적(Personal Travel, Business Travel)
# - class: 등급 (Business, Eco, Eco Plus)
# - flight_distance: 비행 거리
# - inflight_wifi_service: 와이파이 서비스 만족도 (0:N/A; 1-5)
# - departure/arrival_time_convenient: 출발, 도착 시간 만족도 (0:N/A; 1-5)
# - ease_of_online_booking: 온라인 부킹 만족도 (0:N/A; 1-5)
# - gate_location: 게이트 위치 만족도 (0:N/A; 1-5)
# - food_and_drink: 식사와 음료 만족도 (0:N/A; 1-5)
# - online_boarding: 온라인 보딩 만족도 (0:N/A; 1-5)
# - seat_comfort: 좌석 편안함 만족도 (0:N/A; 1-5)
# - inflight_entertainment: 기내 엔터테인먼트 만족도 (0:N/A; 1-5)
# - on-board_service: 온 보드 서비스 만족도 (0:N/A; 1-5)
# - leg_room_service: 다리 공간 만족도 (0:N/A; 1-5)
# - baggage_handling: 수하물 처리 만족도 (0:N/A; 1-5)
# - check-in_service: 체크인 서비스 만족도 (0:N/A; 1-5)
# - inflight_service: 기내 서비스 만족도 (0:N/A; 1-5)
# - cleanliness: 청결 만족도 (0:N/A; 1-5)
# - departure_delay_in_minutes: 출발 지연 시간(분)
# - arrival_delay_in_minutes: 도착 지연 시간(분)
# - **satisfaction: 항공 만족도(1: Satisfaction, 0: Neutral or Dissatisfaction) - Target**

# %%
data.shape
# Out:
# (2580, 24)

# %%
data.head()
# Out:
#        id  gender      customer_type  age   type_of_travel     class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    flight_distance  inflight_wifi_service  departure/arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    ease_of_online_booking  ...  inflight_entertainment  on-board_service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    leg_room_service  baggage_handling  checkin_service  inflight_service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    cleanliness  departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0
#
#    satisfaction
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1
#
# [5 rows x 24 columns]

# %%
data.describe()
# Out:
#                   id          age  flight_distance  inflight_wifi_service  \
# count    2580.000000  2580.000000      2580.000000            2580.000000
# mean    65179.742248    39.229845      1204.824806               2.732558
# std     37320.994433    15.295065      1008.852185               1.317032
# min        54.000000     7.000000        67.000000               0.000000
# 25%     32988.750000    26.000000       405.750000               2.000000
# 50%     64877.000000    40.000000       860.000000               3.000000
# 75%     97717.000000    51.000000      1754.500000               4.000000
# max    129860.000000    85.000000      4963.000000               5.000000
#
#        departure/arrival_time_convenient  ease_of_online_booking  \
# count                        2580.000000             2580.000000
# mean                            3.041473                2.758527
# std                             1.542290                1.400792
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        gate_location  food_and_drink  online_boarding  seat_comfort  \
# count    2580.000000     2580.000000      2580.000000   2580.000000
# mean        2.973256        3.229457         3.242248      3.440310
# std         1.271752        1.341635         1.341842      1.329681
# min         1.000000        0.000000         0.000000      1.000000
# 25%         2.000000        2.000000         2.000000      2.000000
# 50%         3.000000        3.000000         3.000000      4.000000
# 75%         4.000000        4.000000         4.000000      5.000000
# max         5.000000        5.000000         5.000000      5.000000
#
#        inflight_entertainment  on-board_service  leg_room_service  \
# count             2580.000000       2580.000000       2580.000000
# mean                 3.329070          3.361628          3.298450
# std                  1.334021          1.266627          1.313897
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          3.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        baggage_handling  checkin_service  inflight_service  cleanliness  \
# count       2580.000000      2580.000000       2580.000000  2580.000000
# mean           3.599225         3.318992          3.620155     3.277907
# std            1.168210         1.256309          1.182093     1.317367
# min            1.000000         1.000000          0.000000     1.000000
# 25%            3.000000         3.000000          3.000000     2.000000
# 50%            4.000000         3.000000          4.000000     3.000000
# 75%            4.000000         4.000000          5.000000     4.000000
# max            5.000000         5.000000          5.000000     5.000000
#
#        departure_delay_in_minutes  arrival_delay_in_minutes  satisfaction
# count                 2580.000000               2574.000000   2580.000000
# mean                    14.856202                 15.285159      0.427132
# std                     35.808534                 36.301790      0.494758
# min                      0.000000                  0.000000      0.000000
# 25%                      0.000000                  0.000000      0.000000
# 50%                      0.000000                  0.000000      0.000000
# 75%                     13.000000                 14.000000      1.000000
# max                    435.000000                470.000000      1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 2580 non-null   int64
#  1   gender                             2580 non-null   object
#  2   customer_type                      2580 non-null   object
#  3   age                                2580 non-null   int64
#  4   type_of_travel                     2580 non-null   object
#  5   class                              2580 non-null   object
#  6   flight_distance                    2580 non-null   int64
#  7   inflight_wifi_service              2580 non-null   int64
#  8   departure/arrival_time_convenient  2580 non-null   int64
#  9   ease_of_online_booking             2580 non-null   int64
#  10  gate_location                      2580 non-null   int64
#  11  food_and_drink                     2580 non-null   int64
#  12  online_boarding                    2580 non-null   int64
#  13  seat_comfort                       2580 non-null   int64
#  14  inflight_entertainment             2580 non-null   int64
#  15  on-board_service                   2580 non-null   int64
#  16  leg_room_service                   2580 non-null   int64
#  17  baggage_handling                   2580 non-null   int64
#  18  checkin_service                    2580 non-null   int64
#  19  inflight_service                   2580 non-null   int64
#  20  cleanliness                        2580 non-null   int64
#  21  departure_delay_in_minutes         2580 non-null   int64
#  22  arrival_delay_in_minutes           2574 non-null   float64
#  23  satisfaction                       2580 non-null   int64
# dtypes: float64(1), int64(19), object(4)
# memory usage: 483.9+ KB

# %%
data.corr(numeric_only=True).style.background_gradient()
# Out:
# <style type="text/css">
# #T_ffe3e_row0_col0, #T_ffe3e_row1_col1, #T_ffe3e_row2_col2, #T_ffe3e_row3_col3, #T_ffe3e_row4_col4, #T_ffe3e_row5_col5, #T_ffe3e_row6_col6, #T_ffe3e_row7_col7, #T_ffe3e_row8_col8, #T_ffe3e_row9_col9, #T_ffe3e_row10_col10, #T_ffe3e_row11_col11, #T_ffe3e_row12_col12, #T_ffe3e_row13_col13, #T_ffe3e_row14_col14, #T_ffe3e_row15_col15, #T_ffe3e_row16_col16, #T_ffe3e_row17_col17, #T_ffe3e_row18_col18, #T_ffe3e_row19_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ffe3e_row0_col1, #T_ffe3e_row0_col8, #T_ffe3e_row1_col16, #T_ffe3e_row2_col5, #T_ffe3e_row13_col18, #T_ffe3e_row16_col0, #T_ffe3e_row16_col18 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_ffe3e_row0_col2, #T_ffe3e_row2_col0, #T_ffe3e_row3_col9, #T_ffe3e_row9_col3, #T_ffe3e_row15_col4 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_ffe3e_row0_col3, #T_ffe3e_row0_col5, #T_ffe3e_row1_col13, #T_ffe3e_row1_col15, #T_ffe3e_row3_col0, #T_ffe3e_row4_col19, #T_ffe3e_row6_col7, #T_ffe3e_row6_col9, #T_ffe3e_row6_col14, #T_ffe3e_row14_col5, #T_ffe3e_row14_col6, #T_ffe3e_row15_col1, #T_ffe3e_row15_col17, #T_ffe3e_row15_col18, #T_ffe3e_row17_col9, #T_ffe3e_row17_col10, #T_ffe3e_row17_col11, #T_ffe3e_row17_col16, #T_ffe3e_row18_col2, #T_ffe3e_row18_col7, #T_ffe3e_row18_col8, #T_ffe3e_row18_col9, #T_ffe3e_row18_col10, #T_ffe3e_row18_col11, #T_ffe3e_row18_col12, #T_ffe3e_row19_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ffe3e_row0_col4, #T_ffe3e_row0_col10, #T_ffe3e_row0_col12, #T_ffe3e_row1_col6, #T_ffe3e_row1_col7, #T_ffe3e_row4_col9, #T_ffe3e_row5_col7, #T_ffe3e_row5_col9, #T_ffe3e_row7_col18, #T_ffe3e_row10_col6, #T_ffe3e_row12_col7, #T_ffe3e_row14_col3, #T_ffe3e_row15_col7, #T_ffe3e_row17_col0, #T_ffe3e_row17_col1, #T_ffe3e_row17_col6, #T_ffe3e_row18_col1, #T_ffe3e_row18_col3, #T_ffe3e_row18_col6, #T_ffe3e_row19_col17 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_ffe3e_row0_col6, #T_ffe3e_row4_col2, #T_ffe3e_row5_col0, #T_ffe3e_row6_col12, #T_ffe3e_row7_col6, #T_ffe3e_row11_col6, #T_ffe3e_row18_col0, #T_ffe3e_row18_col15, #T_ffe3e_row19_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_ffe3e_row0_col7, #T_ffe3e_row2_col3, #T_ffe3e_row4_col10, #T_ffe3e_row13_col6, #T_ffe3e_row14_col2, #T_ffe3e_row14_col17, #T_ffe3e_row16_col17 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_ffe3e_row0_col9, #T_ffe3e_row0_col14, #T_ffe3e_row0_col17, #T_ffe3e_row5_col2, #T_ffe3e_row9_col0, #T_ffe3e_row13_col2, #T_ffe3e_row16_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_ffe3e_row0_col11, #T_ffe3e_row1_col11, #T_ffe3e_row4_col18, #T_ffe3e_row5_col11, #T_ffe3e_row6_col15, #T_ffe3e_row6_col18, #T_ffe3e_row7_col0, #T_ffe3e_row9_col4, #T_ffe3e_row10_col4, #T_ffe3e_row13_col17, #T_ffe3e_row14_col0, #T_ffe3e_row18_col13 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_ffe3e_row0_col13, #T_ffe3e_row2_col13, #T_ffe3e_row16_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_ffe3e_row0_col15, #T_ffe3e_row5_col12, #T_ffe3e_row8_col13, #T_ffe3e_row12_col5, #T_ffe3e_row14_col4, #T_ffe3e_row16_col13 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_ffe3e_row0_col16, #T_ffe3e_row4_col12, #T_ffe3e_row6_col2, #T_ffe3e_row7_col5, #T_ffe3e_row8_col17, #T_ffe3e_row15_col5, #T_ffe3e_row18_col14 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_ffe3e_row0_col18, #T_ffe3e_row0_col19, #T_ffe3e_row2_col4, #T_ffe3e_row2_col6, #T_ffe3e_row2_col17, #T_ffe3e_row3_col2, #T_ffe3e_row3_col14, #T_ffe3e_row6_col8, #T_ffe3e_row6_col10, #T_ffe3e_row7_col17, #T_ffe3e_row8_col0, #T_ffe3e_row8_col6, #T_ffe3e_row10_col5, #T_ffe3e_row11_col0, #T_ffe3e_row12_col6, #T_ffe3e_row12_col18, #T_ffe3e_row13_col5, #T_ffe3e_row17_col3, #T_ffe3e_row19_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_ffe3e_row1_col0, #T_ffe3e_row4_col0, #T_ffe3e_row5_col16, #T_ffe3e_row6_col0, #T_ffe3e_row10_col17, #T_ffe3e_row10_col18, #T_ffe3e_row11_col17, #T_ffe3e_row11_col18, #T_ffe3e_row13_col1, #T_ffe3e_row16_col5, #T_ffe3e_row17_col2, #T_ffe3e_row17_col15 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ffe3e_row1_col2, #T_ffe3e_row2_col16, #T_ffe3e_row11_col1, #T_ffe3e_row11_col7, #T_ffe3e_row12_col1, #T_ffe3e_row12_col16, #T_ffe3e_row15_col16, #T_ffe3e_row16_col12 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_ffe3e_row1_col3, #T_ffe3e_row2_col18, #T_ffe3e_row9_col17, #T_ffe3e_row16_col6, #T_ffe3e_row17_col19 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_ffe3e_row1_col4, #T_ffe3e_row9_col12, #T_ffe3e_row11_col4, #T_ffe3e_row13_col4 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_ffe3e_row1_col5, #T_ffe3e_row9_col5, #T_ffe3e_row13_col7, #T_ffe3e_row18_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_ffe3e_row1_col8 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_ffe3e_row1_col9, #T_ffe3e_row3_col12, #T_ffe3e_row9_col14 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_ffe3e_row1_col10, #T_ffe3e_row5_col1, #T_ffe3e_row5_col10 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_ffe3e_row1_col12, #T_ffe3e_row1_col17, #T_ffe3e_row1_col18, #T_ffe3e_row4_col7, #T_ffe3e_row4_col16, #T_ffe3e_row5_col14, #T_ffe3e_row8_col18, #T_ffe3e_row10_col0, #T_ffe3e_row15_col6, #T_ffe3e_row17_col5, #T_ffe3e_row18_col19 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_ffe3e_row1_col14, #T_ffe3e_row2_col7, #T_ffe3e_row3_col1, #T_ffe3e_row3_col18, #T_ffe3e_row5_col17, #T_ffe3e_row6_col1, #T_ffe3e_row12_col4, #T_ffe3e_row13_col0, #T_ffe3e_row13_col16, #T_ffe3e_row15_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_ffe3e_row1_col19, #T_ffe3e_row12_col2, #T_ffe3e_row14_col12, #T_ffe3e_row19_col5 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_ffe3e_row2_col1, #T_ffe3e_row2_col11, #T_ffe3e_row2_col12, #T_ffe3e_row4_col15, #T_ffe3e_row8_col12, #T_ffe3e_row14_col16, #T_ffe3e_row16_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_ffe3e_row2_col8, #T_ffe3e_row19_col14 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_ffe3e_row2_col9, #T_ffe3e_row16_col14 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_ffe3e_row2_col10, #T_ffe3e_row8_col11 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_ffe3e_row2_col14, #T_ffe3e_row7_col4, #T_ffe3e_row12_col0, #T_ffe3e_row12_col17, #T_ffe3e_row14_col18, #T_ffe3e_row17_col4, #T_ffe3e_row18_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_ffe3e_row2_col15, #T_ffe3e_row3_col7, #T_ffe3e_row7_col11, #T_ffe3e_row9_col15 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_ffe3e_row2_col19 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_ffe3e_row3_col4, #T_ffe3e_row19_col9 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_ffe3e_row3_col5 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_ffe3e_row3_col6 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_ffe3e_row3_col8, #T_ffe3e_row5_col4 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_ffe3e_row3_col10 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_ffe3e_row3_col11, #T_ffe3e_row11_col9 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_ffe3e_row3_col13 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_ffe3e_row3_col15, #T_ffe3e_row9_col2, #T_ffe3e_row11_col8, #T_ffe3e_row12_col8, #T_ffe3e_row16_col15 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_ffe3e_row3_col16, #T_ffe3e_row4_col13, #T_ffe3e_row4_col14, #T_ffe3e_row10_col1, #T_ffe3e_row10_col14, #T_ffe3e_row14_col1, #T_ffe3e_row15_col3 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_ffe3e_row3_col17, #T_ffe3e_row4_col8, #T_ffe3e_row6_col13, #T_ffe3e_row7_col2, #T_ffe3e_row7_col14, #T_ffe3e_row15_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_ffe3e_row3_col19, #T_ffe3e_row10_col8, #T_ffe3e_row19_col13 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_ffe3e_row4_col1, #T_ffe3e_row7_col3, #T_ffe3e_row12_col9, #T_ffe3e_row14_col10 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_ffe3e_row4_col3 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_ffe3e_row4_col5 {
#   background-color: #8bb2d4;

# %%
sns.heatmap(data.corr(numeric_only=True),
            annot=True, # 숫자 적기
            cmap='Blues', # 색 변환
            cbar=False, # cbar 없애기
            square=True, # 정사각형
            fmt='.3f', # 소숫점 맞추기
            annot_kws={'size' : 5}) # 안쪽 숫자 크기
plt.show()

# %% [markdown]
# # 3.데이터 준비
#
# - 전처리 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# **1) 변수 제거**

# %%
# id, departure/arrival_time_convenient, gate_location, departure_delay_in_minutes
data = data.drop(columns =['id','departure/arrival_time_convenient','gate_location','departure_delay_in_minutes'], axis=1)

# %% [markdown]
# **2) 결측치 제거**

# %%
data.dropna(subset=['arrival_delay_in_minutes'], axis=0, inplace=True)
#data.dropna(inplace=True)

data.isna().sum()
# Out:
# gender                      0
# customer_type               0
# age                         0
# type_of_travel              0
# class                       0
# flight_distance             0
# inflight_wifi_service       0
# ease_of_online_booking      0
# food_and_drink              0
# online_boarding             0
# seat_comfort                0
# inflight_entertainment      0
# on-board_service            0
# leg_room_service            0
# baggage_handling            0
# checkin_service             0
# inflight_service            0
# cleanliness                 0
# arrival_delay_in_minutes    0
# satisfaction                0
# dtype: int64

# %% [markdown]
# **3) x, y 분리**

# %%
target = 'satisfaction'
x = data.drop(columns=target)
y = data.loc[:,target]

# %% [markdown]
# **4) 가변수화**

# %%
# 가변수화
dumm_cols =['gender', 'customer_type', 'type_of_travel', 'class']
x = pd.get_dummies(x, columns=dumm_cols, drop_first=True, dtype=int)

# 확인
x.head()
# Out:
#    age  flight_distance  inflight_wifi_service  ease_of_online_booking  \
# 0   13              460                      3                       3
# 1   25              235                      3                       3
# 2   26             1142                      2                       2
# 3   25              562                      2                       5
# 4   61              214                      3                       3
#
#    food_and_drink  online_boarding  seat_comfort  inflight_entertainment  \
# 0               5                3             5                       5
# 1               1                3             1                       1
# 2               5                5             5                       5
# 3               2                2             2                       2
# 4               4                5             5                       3
#
#    on-board_service  leg_room_service  baggage_handling  checkin_service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    inflight_service  cleanliness  arrival_delay_in_minutes  gender_Male  \
# 0                 5            5                      18.0            1
# 1                 4            1                       6.0            1
# 2                 4            5                       0.0            0
# 3                 4            2                       9.0            0
# 4                 3            3                       0.0            1
#
#    customer_type_disloyal Customer  type_of_travel_Personal Travel  class_Eco  \
# 0                                0                               1          0
# 1                                1                               0          0
# 2                                0                               0          0
# 3                                0                               0          0
# 4                                0                               0          0
#
#    class_Eco Plus
# 0               1
# 1               0
# 2               0
# 3               0
# 4               0

# %% [markdown]
# **5) 학습용, 평가용 데이터 분리**

# %%
# 학습용, 평가용 데이터 분리
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %% [markdown]
# **6) 정규화**

# %%
# 정규화
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(x_train)
x_train_s = scaler.transform(x_train)
x_test_s = scaler.transform(x_test)

# %% [markdown]
# # 4.성능 예측
#
# - 여러 알고리즘으로 만든 모델의 성능을 교차 검증을 통해 예측해 봅니다.
# - 하이퍼파라미터를 설정하지 않고 진행합니다.
# - 예측된 성능 정보를 수집해 마지막에 비교합니다.

# %%
# xgboost 설치
# !pip install xgboost

# %%
# lightgbm 설치
# !pip install lightgbm

# %% [markdown]
# - 이후 사용할 함수를 모두 불러옵니다.

# %%
# 불러오기
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# **1) KNN**
#
# - KNN 모델의 성능을 교차 검증을 통해 예측해 봅니다.

# %%
cv_score = cross_val_score(KNeighborsClassifier(), x_train_s, y_train, cv=5)

# 결과확인
print('평균:', cv_score.mean())

# 결과수집
result = {}
result['KNN'] = cv_score.mean()
# Out:
# 평균: 0.8783856571252693

# %% [markdown]
# **2) Decision Tree**
#
# - Decision Tree 모델의 성능을 교차 검증을 통해 예측해 봅니다.

# %%
# 성능예측
cv_score = cross_val_score(DecisionTreeClassifier(), x_train, y_train, cv=5)

# 결과확인
print('평균:', cv_score.mean())

# 결과수집
result['Decision Tree'] = cv_score.mean()
# Out:
# 평균: 0.8983933518005539

# %% [markdown]
# **3) Logistic Regression**
#
# - Logistic Regression 모델의 성능을 교차 검증을 통해 예측해 봅니다.

# %%
# 성능예측
cv_score = cross_val_score(LogisticRegression(), x_train, y_train, cv=5)

# 결과확인
print('평균:', cv_score.mean())

# 결과수집
result['Logistic Regression'] = cv_score.mean()
# Out:
# 평균: 0.8189996922129886

# %% [markdown]
# **4) Random Forest**
#
# - Random Forest 모델의 성능을 교차 검증을 통해 예측해 봅니다.

# %%
# 성능예측
cv_score = cross_val_score(RandomForestClassifier(), x_train, y_train, cv=5)

# 결과확인
print('평균:', cv_score.mean())

# 결과수집
result['Random Forest'] = cv_score.mean()
# Out:
# 평균: 0.9217066789781472

# %% [markdown]
# **5) XGBoost**
#
# - XGBoost 모델의 성능을 교차 검증을 통해 예측해 봅니다.

# %%
# 성능예측
cv_score = cross_val_score(XGBClassifier(), x_train, y_train, cv=5)

# 결과확인
print('평균:', cv_score.mean())

# 결과수집
result['XGBoost'] = cv_score.mean()
# Out:
# 평균: 0.9317020621729764

# %% [markdown]
# **6) LightGBM**
#
# - LightGBM 모델의 성능을 교차 검증을 통해 예측해 봅니다.

# %%
# 성능예측
cv_score = cross_val_score(LGBMClassifier(verbose=-1), x_train, y_train, cv=5)

# 결과확인
print('평균:', cv_score.mean())

# 결과수집
result['LightGBM'] = cv_score.mean()
# Out:
# 평균: 0.9344798399507541

# %% [markdown]
# # 5.결과 확인
#
# - 예측된 각 모델의 성능을 비교합니다.

# %%
# 성능 비교
print('=' * 40)
for m_name, score in result.items():
    print(m_name, score.round(3))
print('=' * 40)
# Out:
# ========================================
# KNN 0.878
# Decision Tree 0.898
# Logistic Regression 0.819
# Random Forest 0.922
# XGBoost 0.932
# LightGBM 0.934
# ========================================

# %% [markdown]
# # 6.성능 튜닝
#
# - 위에서 성능이 가장 좋을 것으로 예측된 알고리즘으로 모델링합니다.
# - 본 실습에서는 하이퍼파라미터가 최적화된 LightGBM 모델을 만듭니다.
# - joblib.dump() 함수를 사용해 모델을 파일로 저장합니다.

# %%
# 파라미터
param = {'max_depth': range(1, 21)}

# 모델선언
model = GridSearchCV(LGBMClassifier(verbose=-1), param, cv=5)

# 학습하기(많은 시간이 소요될 수 있음)
model.fit(x_train, y_train)

# 최적 파라미터, 예측 최고 성능
print(model.best_params_)
print(model.best_score_)
# Out:
# {'max_depth': 18}
# 0.9355894121268081

# %%
# 변수 중요도 시각화
plt.figure(figsize=(6, 5))
plt.barh(list(x), model.best_estimator_.feature_importances_)
plt.show()

# %%
# 모델 저장
joblib.dump(model, 'airline_model_final.pkl')
# Out:
# ['airline_model_final.pkl']

# %% [markdown]
# # 7.성능 평가
#
# - 최적 파라미터로 학습된 모델에 대해 최종 성능 평가를 진행합니다.

# %%
y_pred = model.predict(x_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[424  10]
#  [ 34 305]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       434
#            1       0.97      0.90      0.93       339
#
#     accuracy                           0.94       773
#    macro avg       0.95      0.94      0.94       773
# weighted avg       0.94      0.94      0.94       773
