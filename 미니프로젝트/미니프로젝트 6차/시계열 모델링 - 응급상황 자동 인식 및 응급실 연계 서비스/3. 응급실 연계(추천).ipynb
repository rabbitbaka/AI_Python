# %% [markdown]
# # **응급상황 자동 인식 및 응급실 연계 서비스**
# # **단계3 : 응급상황 연계(추천)**

# %% [markdown]
# ## **0.미션**
#
# 단계 3에서는, 응급상황의 음성을 인식해서 텍스트로 변환하고, 변환된 텍스트를 다시 요약 및 핵심키워드 도출 작업을 수행합니다.
# 이를 위해 사전학습된 모델을 API로 연결하여 활용합니다.

# %% [markdown]
# ### 미션4 : 응급실 추천
# * 응급실 위치와 응급전화 발신자 위치 기반 추천
# * 두 좌표간 직선거리(Haversine)
#     * 1) 500여 곳 응급실에 대해서, 거리 기반 가까운 응급실 찾기
#     * 2) 좌표 구간을 설정하여 대상 응급실 범위를 좁힌 후, 거리 기반 가까운 응급실 찾기

# %% [markdown]
# ## **1.환경설정**

# %% [markdown]
# ### (1) 경로 설정
#
# 구글 드라이브 연결

# %% [markdown]
# #### 1) 구글 드라이브 폴더 생성
# * 새 폴더(project6_2)를 생성하고
# * 제공 받은 파일을 업로드

# %% [markdown]
# #### 2) 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project6_2/'

# %% [markdown]
# ### (2) 라이브러리

# %% [markdown]
# #### 1) 필요한 라이브러리 설치

# %% [markdown]
# * requirements.txt 파일의 [경로 복사]를 한 후,
# * 아래 경로에 붙여 넣기

# %%
# 경로 : /content/drive/MyDrive/project6_2/requirements.txt
# 경로가 다른 경우 아래 코드의 경로 부분을 수정하세요.

# !pip install -r /content/drive/MyDrive/project6_2/requirements.txt
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (1.54.4)
# Collecting datasets (from -r /content/drive/MyDrive/project6_2/requirements.txt (line 2))
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting haversine (from -r /content/drive/MyDrive/project6_2/requirements.txt (line 3))
#   Downloading haversine-2.8.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (2.32.3)
# Collecting xxhash (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2))
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2))
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2))
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (3.11.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai->-r /content/drive/MyDrive/project6_2/requirements.txt (line 1)) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->-r /content/drive/MyDrive/project6_2/requirements.txt (line 2)) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 21.2 MB/s eta 0:00:00
# Downloading haversine-2.8.1-py2.py3-none-any.whl (7.7 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, haversine, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 haversine-2.8.1 multiprocess-0.70.16 xxhash-3.5.0

# %% [markdown]
# #### 2) 라이브러리 로딩

# %%
#필요한 라이브러리 설치 및 불러우기
import os
import pandas as pd
import numpy as np

from haversine import haversine
import requests
import json

# 더 필요한 라이브러리 추가 -------------

# %% [markdown]
# ### (3) 데이터 로딩
# * 단계1에서 수집한 응급실 정보를 불러와서 데이터프레임으로 저장합니다.

# %%
patient = pd.read_excel(path + 'audio_location.xlsx')

# %%
patient
# Out:
#       filename         위도          경도
# 0   audio1.mp3  37.358618  127.115036
# 1   audio2.mp3  36.815571  127.128844
# 2   audio3.mp3  37.538435  126.989828
# 3   audio4.mp3  35.185745  129.076541
# 4   audio5.mp3  36.503544  127.252941
# 5          1_1  37.566500  126.978000
# 6          1_2  35.179600  129.075600
# 7          2_1  35.871400  128.601400
# 8          2_2  37.456300  126.705200
# 9          3_1  35.159500  126.852600
# 10         3_2  36.350400  127.384500
# 11         4_1  35.538400  129.311400
# 12         4_2  33.499600  126.531200
# 13         5_1  37.263600  127.028600
# 14         5_2  37.881300  127.729800

# %%
data = pd.read_csv(path + '응급실정보.csv')

# %%
data
# Out:
#                  기관명                                              주소  \
# 0    (의)내경의료재단울산제일병원                      울산광역시 남구 남산로354번길 26 (신정동)
# 1      (의)서일의료재단기장병원                         부산광역시 기장군 기장읍 대청로72번길 6
# 2    (의)성세의료재단 뉴성민병원  인천광역시 서구 칠천왕로33번길 17 (석남동, 신석로 70(석남1동, 성민병원))
# 3     (의)영문의료재단다보스병원       경기도 용인시 처인구 백옥대로1082번길 18, 다보스종합병원 (김량장동)
# 4    (의)효심의료재단용인서울병원                        경기도 용인시 처인구 고림로 81 (고림동)
# ..               ...                                             ...
# 520      효산의료재단안양샘병원                  경기도 안양시 만안구 삼덕로 9 (안양동, 안양샘병원)
# 521       효산의료재단지샘병원               경기도 군포시 군포로 591 (당동, (G샘병원)군포샘병원)
# 522           효성시티병원                       부산광역시 해운대구 해운대로 135 (재송동)
# 523             흑룡의원                           인천광역시 옹진군 백령면 백령로 831
# 524             희명병원                        서울특별시 금천구 시흥대로 244 (시흥동)
#
#       응급의료기관종류           대표전화          응급실전화         위도          경도
# 0    응급실운영신고기관   052-220-3300   052-220-3334  35.548238  129.307011
# 1     지역응급의료기관   051-723-0171   051-723-2119  35.236029  129.216492
# 2     지역응급의료기관   032-726-1000   032-726-1190  37.508994  126.669479
# 3     지역응급의료센터  031-8021-2114  031-8021-2130  37.234641  127.210499
# 4     지역응급의료기관   031-337-0114   031-336-0119  37.240316  127.214491
# ..         ...            ...            ...        ...         ...
# 520   지역응급의료센터   031-467-9717   031-467-9119  37.393404  126.924477
# 521   지역응급의료센터   031-389-3000   031-389-3119  37.358645  126.947360
# 522  응급실운영신고기관   051-709-3000   051-709-3119  35.185413  129.121459
# 523  응급실운영신고기관   032-837-6873   032-837-3153  37.959524  124.665499
# 524   지역응급의료기관    02-804-0002    02-809-0122  37.455671  126.900563
#
# [525 rows x 7 columns]

# %% [markdown]
# ## **2. 응급실 추천**

# %% [markdown]
# ### (1) 직선거리 계산
# - haversine formula
#     * Haversine은 두 지점 간의 거리를 구할 때 사용하는 수학 공식으로, 지구의 구형 구조를 고려하여 위도와 경도를 기반으로 직선 거리를 계산한다.
# - 세부사항
#     * 하버사인 함수를 활용

# %% [markdown]
# #### 1) 하버사인 함수 사용 연습
# * 임의의 두 좌표간 거리 계산
#     * 응급실 데이터프레임을 열어서
#     * 응급실 두 곳의 좌표를 확인하고
#     * 두 지점의 거리를 계산해 봅시다
# * 사용법 : haversine((위도1, 경도1), (위도2, 경도2), unit='km')

# %%
haversine((data['위도'][0], data['경도'][0]), (37.3586184462591, 127.115035898293), unit='km')
# Out:
# 280.9774581542671

# %% [markdown]
# #### 2) 가장 가까운 응급실 3곳 추천하기1
# * 세부사항
#     * 입력된 좌표와 전체 응급실과 거리를 계산한 후
#     * 가장 가까운 거리의 응급실 3 곳을 반환합니다.
# * 이를 함수로 생성하고 테스트 해 봅시다.

# %%
# 입력된 좌표와 전체 응급실과의 거리 계산
# 가장 가아운 거리 응급실 3곳을 반환

# %%
input = (patient['위도'][0], patient['경도'][0])

# %%
# 가장 가까운 거리의 응급실 3곳 반환
def recommend_hospital1(input, data):
    # 거리 계산 및 정렬
    nearest = sorted(
        data.itertuples(index=False),
        key=lambda row: haversine(input, (row.위도, row.경도), unit='km')
    )
    # 가장 가까운 top_n 응급실 반환
    return {
        row.기관명: haversine(input, (row.위도, row.경도), unit='km')
        for row in nearest[:3]
    }

# %%
# 결과 출력
result1 = recommend_hospital1(input, data)
print(result1)
# Out:
# {'분당서울대학교병원': 1.111161722006186, '대진의료재단분당제생병원': 3.29996370427956, '국군수도병원': 4.7388990676761376}

# %%
result1 = pd.DataFrame(result1.items(), columns=['기관명', '거리'])
result1
# Out:
#             기관명        거리
# 0     분당서울대학교병원  1.111162
# 1  대진의료재단분당제생병원  3.299964
# 2        국군수도병원  4.738899

# %% [markdown]
# #### 3) 가장 가까운 응급실 3곳 추천하기2
# * 문제점 : 입력 받은 좌표와 응급실 전체와의 거리를 모두 계산하는 것은 비효율 적입니다.
# * 해결 방안 : 그래서 입력 받은 좌표를 기준으로 일정 범위 내에 해당되는 응급실에 대해서 거리를 계산하고 추천하도록 기존 함수를 수정 합니다.
# * hint :
#     * 입력 받은 위도, 경도 값에 ± α 하여 일정 범위 구간을 정하고
#     * 응급실 정보에서 해당 구간을 먼저 조회한 후
#     * 거리 계산

# %%
# 일정범위 네모안에서 찾아보고(위도, 경도 값에 ± α), 응급실 정보에서 해당 구간을 먼저 조회한 후, 거리를 계산하여 3곳 추천하기

# %%
def recommend_hospital2(input, data, alpha=0.1, top_n=3):

    while True:
        # 범위 계산
        lat_min, lat_max = input[0] - alpha, input[0] + alpha
        lon_min, lon_max = input[1] - alpha, input[1] + alpha

        # 범위 내 좌표 필터링
        filtered_data = data[
            (data['위도'] >= lat_min) & (data['위도'] <= lat_max) &
            (data['경도'] >= lon_min) & (data['경도'] <= lon_max)
        ]

        # 응급실이 top_n개 이상인 경우 종료
        if len(filtered_data) >= top_n:
            break

        # α 값 증가
        alpha *= 1.5  # 증가율 조정 가능

    # 거리 계산 및 정렬
    nearest = sorted(
        filtered_data.itertuples(index=False),
        key=lambda row: haversine(input, (row.위도, row.경도), unit='km')
    )

    # 가장 가까운 top_n 응급실 반환
    return {
        row.기관명: haversine(input, (row.위도, row.경도), unit='km')
        for row in nearest[:top_n]
    }

# %%
# 결과 출력
result2 = recommend_hospital2(input, data)
print(result2)
# Out:
# {'분당서울대학교병원': 1.111161722006186, '대진의료재단분당제생병원': 3.29996370427956, '국군수도병원': 4.7388990676761376}

# %%
result2 = pd.DataFrame(result2.items(), columns=['기관명', '거리'])
result2
# Out:
#             기관명        거리
# 0     분당서울대학교병원  1.111162
# 1  대진의료재단분당제생병원  3.299964
# 2        국군수도병원  4.738899

# %% [markdown]
# ### (2) [조 과제]고도화 : naver 지도 api 사용
#
# * 이 부분은 조별 과제로 수행하게 됩니다.(개인과제 아님!)
#
# * 세부사항
#     * 두 지점간, 최단 도로거리, 소요 시간을 계산하는 함수를 생성하시오.
#     * 함수 내용
#         * 입력 : 두 지점의 위도, 경도, 네이버클라우드id, 암호키
#         * 출력 : 도로거리(km)
#
#     * 네이버 Maps API 활용
#         * 사용할 API : Direction 5
#         * 가이드 : https://guide.ncloud-docs.com/docs/ko/maps-direction5-api
#         * 가이드를 활용해서 url, header, params를 구성합니다.
#         * params의 옵션은 'trafast' (실시간 빠른 길 옵션)을 선택하시오.

# %% [markdown]
# #### 1) maps 클라이언트ID, 키 로딩

# %%
with open(path + 'map_key.txt', 'r') as file:
    key = json.load(file)

# 딕셔너리에서 값 추출
c_id = key['c_id']  # 예시 키 이름
c_key = key['c_key']  # 예시 키 이름

# %% [markdown]
# #### 2) 함수 생성

# %%
def get_dist(start_lat, start_lng, dest_lat, dest_lng, c_id, c_key):
    url = "https://naveropenapi.apigw.ntruss.com/map-direction/v1/driving"
    headers = {
        "X-NCP-APIGW-API-KEY-ID": c_id,
        "X-NCP-APIGW-API-KEY": c_key,
    }
    params = {
        "start": f"{start_lng},{start_lat}",  # 출발지 (경도, 위도)
        "goal": f"{dest_lng},{dest_lat}",    # 목적지 (경도, 위도)
        "option": "trafast"  # 실시간 빠른 길 옵션
    }

    # 요청하고, 답변 받아오기
    response =  requests.get(url, headers=headers, params=params)

    # 응답 상태 코드 확인
    if response.status_code == 200:  # 성공
        data = response.json()
        # 거리 추출
        dist = data['route']['trafast'][0]['summary']['distance']  # m(미터)
        return dist
    else:  # 실패
        raise Exception(f"API 호출 실패: {response.status_code}, {response.text}")

# %% [markdown]
# * 테스트

# %%
get_dist(patient['위도'][0], patient['경도'][0], data['위도'][0], data['경도'][0], c_id, c_key)
# Out:
# 354566

# %% [markdown]
# #### 3) 응급실 추천
# * recommend_hospital2 함수를 참조해서 recommend_hospital3 만들기
#     * 거리 계산 부분을 get_dist 함수로 대체
#     * 입력 부분 수정

# %%
def recommend_hospital3(input, data, c_id, c_key, alpha=0.1, top_n=3):
    while True:
        # 범위 계산
        lat_min, lat_max = input[0] - alpha, input[0] + alpha
        lon_min, lon_max = input[1] - alpha, input[1] + alpha

        # 범위 내 좌표 필터링
        filtered_data = data[
            (data['위도'] >= lat_min) & (data['위도'] <= lat_max) &
            (data['경도'] >= lon_min) & (data['경도'] <= lon_max)
        ]

        # 응급실이 top_n개 이상인 경우 종료
        if len(filtered_data) >= top_n:
            break

        # α 값 증가
        alpha *= 1.5  # 증가율 조정 가능

    # 거리 계산 및 정렬
    nearest = sorted(
        filtered_data.itertuples(index=False),
        key=lambda row: get_dist(input[0],input[1],row.위도, row.경도, c_id, c_key)
    )

    # 가장 가까운 top_n 응급실 반환
    return {
        row.기관명: get_dist(input[0],input[1],row.위도, row.경도, c_id, c_key)
        for row in nearest[:top_n]
    }

# %%
result3 = recommend_hospital3(input,data, c_id, c_key)
result3
# Out:
# {'분당서울대학교병원': 2626, '대진의료재단분당제생병원': 4707, '국군수도병원': 5973}

# %%
result3 = pd.DataFrame(result3.items(), columns=['기관명', '거리(m)'])
result3
# Out:
#             기관명  거리(m)
# 0     분당서울대학교병원   2626
# 1  대진의료재단분당제생병원   4707
# 2        국군수도병원   5973

# %%
data = pd.read_csv(path + '응급실정보.csv')
data.head()
# DataFrame 생성
emergency_df = pd.DataFrame(data)

# 응급기관 데이터를 리스트로 변환
emergency_locations = []

for _, row in emergency_df.iterrows():
    emergency_locations.append({"name": row["기관명"], "coords": (row["위도"], row["경도"])})

# 결과 출력
emergency_locations
# Out:
# [{'name': '(의)내경의료재단울산제일병원',
#   'coords': (35.54823820112527, 129.30701143429678)},
#  {'name': '(의)서일의료재단기장병원', 'coords': (35.23602946449906, 129.21649161387128)},
#  {'name': '(의)성세의료재단 뉴성민병원', 'coords': (37.5089936801167, 126.669478649026)},
#  {'name': '(의)영문의료재단다보스병원',
#   'coords': (37.234641294534285, 127.21049868474802)},
#  {'name': '(의)효심의료재단용인서울병원', 'coords': (37.240316373, 127.2144914405)},
#  {'name': '(재)미리내천주성삼성직수도회천주성삼병원',
#   'coords': (35.84022544517349, 128.70573339664242)},
#  {'name': 'KS병원', 'coords': (35.197963178976366, 126.83322475289852)},
#  {'name': '가톨릭관동대학교국제성모병원', 'coords': (37.54237265391807, 126.6836048687878)},
#  {'name': '가톨릭대학교 인천성모병원', 'coords': (37.4845586499062, 126.724708130675)},
#  {'name': '가톨릭대학교부천성모병원', 'coords': (37.4874477394264, 126.79243459155)},
#  {'name': '가톨릭대학교성빈센트병원', 'coords': (37.27792234538125, 127.02744945028702)},
#  {'name': '가톨릭대학교여의도성모병원', 'coords': (37.51827233800711, 126.93673129599132)},
#  {'name': '가톨릭대학교은평성모병원', 'coords': (37.63360840972685, 126.91615048739686)},
#  {'name': '가톨릭대학교의정부성모병원', 'coords': (37.75865547828227, 127.07767290194454)},
#  {'name': '강남고려병원', 'coords': (37.4856188363947, 126.956781703053)},
#  {'name': '강남더드림병원', 'coords': (37.5009902618151, 127.050967336445)},
#  {'name': '강남베드로병원', 'coords': (37.48561217992573, 127.0395873429168)},
#  {'name': '강남병원', 'coords': (37.27377983891884, 127.11140719951388)},
#  {'name': '강남종합병원', 'coords': (35.88300855242191, 128.66345602650745)},
#  {'name': '강남힐병원', 'coords': (37.4816513439454, 126.911648078471)},
#  {'name': '강동경희대학교의대병원', 'coords': (37.5520459324005, 127.157084787845)},
#  {'name': '강릉아산병원', 'coords': (37.81842668503607, 128.85771413305145)},
#  {'name': '강병원', 'coords': (34.97415924940364, 128.32528942283565)},
#  {'name': '강북삼성병원', 'coords': (37.56849763123383, 126.96793805451702)},
#  {'name': '강북으뜸병원', 'coords': (37.6254205559935, 127.026184524499)},
#  {'name': '강서케이병원', 'coords': (37.5373576230977, 126.836699017573)},
#  {'name': '강원대학교병원', 'coords': (37.87497158192399, 127.74448573764938)},
#  {'name': '강원특별자치도강릉의료원', 'coords': (37.74931042017154, 128.8887963251862)},
#  {'name': '강원특별자치도삼척의료원', 'coords': (37.44027922704624, 129.16370014395005)},
#  {'name': '강원특별자치도속초의료원', 'coords': (38.21622784728713, 128.5891194514502)},
#  {'name': '강원특별자치도영월의료원', 'coords': (37.186588403987926, 128.46530529870284)},
#  {'name': '강원특별자치도원주의료원', 'coords': (37.332496031537154, 127.94896203327232)},
#  {'name': '강일병원', 'coords': (35.2567043538, 128.869611099)},
#  {'name': '의)근원의료재단경산중앙병원', 'coords': (35.80882731345708, 128.7401572913474)},
#  {'name': '의령병원', 'coords': (35.31860563079656, 128.2586798056445)},
#  {'name': '의료법인 갑을의료재단 갑을녹산병원',
#   'coords': (35.090573808412124, 128.85332092602837)},
#  {'name': '의료법인 거명의료재단 영광기독병원',
#   'coords': (35.274959355007304, 126.5108758767997)},
#  {'name': '의료법인 광혜의료재단 광혜병원',
#   'coords': (35.207033333333335, 129.07113611111112)},
#  {'name': '의료법인 길의료재단 길병원', 'coords': (37.45208024654252, 126.70916173607196)},
#  {'name': '의료법인 루가의료재단 나은병원', 'coords': (37.4890534064866, 126.679450677348)},
#  {'name': '의료법인 문병욱의료재단 진주고려병원',
#   'coords': (35.17849131749577, 128.09223855742437)},
#  {'name': '의료법인 성념의료재단맑은샘병원',
#   'coords': (34.89793483097861, 128.64371778461182)},
#  {'name': '의료법인 성수의료재단 인천백병원', 'coords': (37.4772581429266, 126.648504056866)},
#  {'name': '의료법인 센텀의료재단 센텀종합병원',
#   'coords': (35.16637129021226, 129.11466833709284)},
#  {'name': '의료법인 영제 의료재단 엔케이세종병원',
#   'coords': (36.47962250753158, 127.26225618927695)},
#  {'name': '의료법인 온그룹의료재단 온종합병원',
#   'coords': (35.15787735996765, 129.04998435792845)},
#  {'name': '의료법인 우범의료재단 장흥종합병원',
#   'coords': (34.67726071666993, 126.91093606650924)},
#  {'name': '의료법인 은성의료재단 좋은강안병원',
#   'coords': (35.15015905669445, 129.11072434834875)},
#  {'name': '의료법인 이도의료재단 남해병원',
#   'coords': (34.84640603127717, 127.89425156305388)},
#  {'name': '의료법인 인당의료재단 부민병원',
#   'coords': (35.21191431805676, 129.0112123286087)},
#  {'name': '의료법인 인당의료재단 해운대부민병원',
#   'coords': (35.16142040775608, 129.1556561002225)},
#  {'name': '의료법인 일심의료재단 포천우리병원',
#   'coords': (37.827495913257785, 127.1481437183119)},
#  {'name': '의료법인 중앙의료재단 중앙병원',
#   'coords': (33.49234614827984, 126.47058708143307)},
#  {'name': '의료법인 행도의료재단 해동병원',
#   'coords': (35.09194298219175, 129.04386428258525)},
#  {'name': '의료법인 현경의료재단 광양서울병원',
#   'coords': (34.957912006875524, 127.69055714590516)},
#  {'name': '의료법인 혜인의료재단 한국병원', 'coords': (33.500185921027, 126.51698873048466)},
#  {'name': '의료법인갈렌의료재단박병원', 'coords': (37.0482647009, 127.0570038575)},
#  {'name': '의료법인갑을의료재단갑을장유병원',
#   'coords': (35.208667155880995, 128.80564300531228)},
#  {'name': '의료법인강릉동인병원', 'coords': (37.77432579461282, 128.90714180258507)},
#  {'name': '의료법인거붕백병원', 'coords': (34.873675809023304, 128.62605696825915)},
#  {'name': '의료법인건명의료재단중앙제일병원',
#   'coords': (36.85848747628605, 127.44050791116804)},
#  {'name': '의료법인구의료재단구병원', 'coords': (35.85082313699737, 128.54148303217696)},
#  {'name': '의료법인나사렛의료재단나사렛국제병원',
#   'coords': (37.4079911136402, 126.67046935782248)},
#  {'name': '의료법인남촌의료재단시화병원', 'coords': (37.349955639806, 126.736970968751)},
#  {'name': '의료법인녹산의료재단동수원병원', 'coords': (37.27816562305189, 127.0343637912553)},
#  {'name': '의료법인대광의료재단괴산성모병원',
#   'coords': (36.81544387632933, 127.78424628538971)},
#  {'name': '의료법인대남의료재단청도대남병원',
#   'coords': (35.64871261648798, 128.73711323398672)},
#  {'name': '의료법인대산의료재단익산병원', 'coords': (35.96168123354797, 126.96649966881398)},
#  {'name': '의료법인대우의료재단대우병원', 'coords': (34.87222152119712, 128.72216421007292)},
#  {'name': '의료법인대인의료재단다니엘종합병원',
#   'coords': (37.51232155788357, 126.76948894065184)},
#  {'name': '의료법인덕산의료재단김천제일병원',
#   'coords': (36.13534199566352, 128.11882383545816)},
#  {'name': '의료법인동강의료재단동강병원', 'coords': (35.55340950863559, 129.30194290200075)},
#  {'name': '의료법인동강의료재단동천동강병원', 'coords': (35.5685460268, 129.350477985)},
#  {'name': '의료법인동신의료재단동신병원', 'coords': (37.58110428173239, 126.93658306608872)},
#  {'name': '의료법인동춘의료재단문경제일병원', 'coords': (36.5848214366, 128.189771534)},
#  {'name': '의료법인동해동인병원', 'coords': (37.530006805605616, 129.1074043067605)},
#  {'name': '의료법인록향의료재단신천연합병원',
#   'coords': (37.44454605843136, 126.78938385106557)},
#  {'name': '의료법인명성의료재단영양병원', 'coords': (36.66257764096643, 129.1173135291313)},
#  {'name': '의료법인명인의료재단화홍병원', 'coords': (37.2601427452511, 126.963891671858)},
#  {'name': '의료법인명지의료재단명지병원', 'coords': (37.1630057642892, 128.23405656001103)},
#  {'name': '의료법인명지의료재단명지병원', 'coords': (37.64207169115689, 126.83145733035823)},
#  {'name': '의료법인목포구암의료재단목포중앙병원',
#   'coords': (34.8208073192579, 126.421380872161)},
#  {'name': '의료법인바른의료재단바른병원',
#   'coords': (35.179208158439586, 128.09170475475878)},
#  {'name': '의료법인박애의료재단박애병원', 'coords': (36.99308383421509, 127.08907896026508)},
#  {'name': '의료법인백송의료재단굿모닝병원', 'coords': (36.9905734199, 127.120463688)},
#  {'name': '의료법인백제병원', 'coords': (36.19250243074026, 127.09436976296004)},
#  {'name': '의료법인백천의료재단바로본병원',
#   'coords': (35.86845464452633, 128.61518371219722)},
#  {'name': '의료법인보광의료재단속초보광병원',
#   'coords': (38.19802124533656, 128.57838660480326)},
#  {'name': '의료법인삼백의료재단상주성모병원',
#   'coords': (36.42029125774357, 128.15973341130405)},
#  {'name': '의료법인삼호의료재단벌교삼호병원',
#   'coords': (34.833846754024535, 127.34573228719375)},
#  {'name': '의료법인생명사랑의료재단밀양윤병원',
#   'coords': (35.48468031922943, 128.75564526263582)},
#  {'name': '의료법인서명의료재단세명종합병원',
#   'coords': (35.82621911080917, 128.7374074375532)},
#  {'name': '의료법인서울효천의료재단에이치플러스양지병원',
#   'coords': (37.48427507045319, 126.93253922577289)},
#  {'name': '의료법인서준의료재단예천권병원',
#   'coords': (36.65741644988633, 128.45890491333589)},
#  {'name': '의료법인서해병원', 'coords': (36.08449428686221, 126.6875810614244)},
#  {'name': '의료법인석경의료재단센트럴병원',
#   'coords': (37.336409472880064, 126.72768862827667)},
#  {'name': '의료법인석영의료재단창원제일종합병원',
#   'coords': (35.199036071110854, 128.56772923734115)},
#  {'name': '의료법인석천재단고창병원', 'coords': (35.43645131091079, 126.69331814963527)},
#  {'name': '의료법인성광의료재단일산차병원',
#   'coords': (37.65413326289407, 126.77574306091104)},
#  {'name': '의료법인성심의료재단양구성심병원', 'coords': (38.1047788862656, 127.99119726275)},
#  {'name': '의료법인성지의료재단성지병원', 'coords': (37.3452989790958, 127.954009227598)},
#  {'name': '의료법인성화의료재단대한병원', 'coords': (37.63547043209498, 127.02267251878474)},
#  {'name': '의료법인송암의료재단마이크로병원',
#   'coords': (36.63402150390528, 127.45009452402525)},
#  {'name': '의료법인송은의료재단울산시티병원',
#   'coords': (35.58285370330335, 129.35905740278503)},
#  {'name': '의료법인숭인의료재단김해복음병원', 'coords': (35.2304897832, 128.8935457971)},
#  {'name': '의료법인승연의료재단 삼천포서울병원',
#   'coords': (34.93302179207928, 128.08012015415227)},
#  {'name': '의료법인신안대우병원', 'coords': (34.722263099542104, 125.93256566497465)},
#  {'name': '의료법인신의료재단김해삼승병원', 'coords': (35.226730571, 128.8821901808)},
#  {'name': '의료법인안동병원', 'coords': (36.54691448006022, 128.70097021920307)},
#  {'name': '의료법인양진의료재단평택성모병원',
#   'coords': (37.008809910565546, 127.07371568769604)},
#  {'name': '의료법인에스엠씨의료재단울산세민병원',
#   'coords': (35.556584160908145, 129.33096884743864)},
#  {'name': '의료법인영경의료재단전주병원', 'coords': (35.81502660230338, 127.1247991889436)},
#  {'name': '의료법인영경의료재단호성전주병원',
#   'coords': (35.865528416459995, 127.14790290638275)},
#  {'name': '의료법인영동의료재단의정부백병원',
#   'coords': (37.74536735722315, 127.0620670982038)},
#  {'name': '의료법인영서의료재단천안충무병원',
#   'coords': (36.79739687904163, 127.1315782043232)},
#  {'name': '의료법인영성의료재단고흥종합병원', 'coords': (34.620393082853, 127.293713733344)},
#  {'name': '의료법인영암의료재단고령영생병원',
#   'coords': (35.72995531573922, 128.27201138885076)},
#  {'name': '의료법인영제의료재단영남제일병원',
#   'coords': (36.38925516777733, 128.43429486266444)},
#  {'name': '의료법인영훈의료재단대전선병원', 'coords': (36.3359621088938, 127.41011056508802)},
#  {'name': '의료법인영훈의료재단유성선병원',
#   'coords': (36.37535496572087, 127.32491359339664)},
#  {'name': '의료법인예당의료재단예산종합병원',
#   'coords': (36.69111403683895, 126.83810397105952)},
#  {'name': '의료법인오성의료재단동군산병원',
#   'coords': (35.97740074466571, 126.73719225835914)},
#  {'name': '의료법인왜관병원', 'coords': (35.99606388888889, 128.4015222222222)},
#  {'name': '의료법인우리의료재단김포우리병원',
#   'coords': (37.632530143647166, 126.7105272263707)},
#  {'name': '의료법인원광의료재단원광종합병원', 'coords': (37.2100621333, 127.0080345889)},
#  {'name': '의료법인은성의료재단좋은삼선병원', 'coords': (35.1505677387241, 129.0081978825217)},
#  {'name': '의료법인은성의료재단좋은삼정병원',
#   'coords': (35.55282641650826, 129.26899792409964)},
#  {'name': '의료법인은성의료재단좋은선린병원',
#   'coords': (36.04808906149477, 129.36704339734024)},
#  {'name': '의료법인은혜와감사의료재단화성중앙종합병원',
#   'coords': (37.13118966594901, 126.910365631779)},
#  {'name': '의료법인인봉의료재단뉴고려병원',
#   'coords': (37.64095507933562, 126.66022763544731)},
#  {'name': '의료법인인봉의료재단영등포병원', 'coords': (37.526858089517, 126.89561402986)},
#  {'name': '의료법인인성의료재단한림병원', 'coords': (37.53218449100167, 126.73435495537971)},
#  {'name': '의료법인인성의료재단함평성심병원',
#   'coords': (35.061886111111114, 126.51980555555556)},
#  {'name': '의료법인인화재단한국병원', 'coords': (36.61950588971749, 127.49659485930336)},
#  {'name': '의료법인일산복음병원', 'coords': (37.68205457051212, 126.7801254241406)},
#  {'name': '의료법인자산의료재단제천서울병원',
#   'coords': (37.13857101389598, 128.20613928597675)},
#  {'name': '의료법인자인의료재단(더자인병원)',
#   'coords': (37.62297864974611, 126.83568238933726)},
#  {'name': '의료법인장호의료재단녹동현대병원',
#   'coords': (34.5461939078177, 127.14569777683867)},
#  {'name': '의료법인정민의료재단보은한양병원',
#   'coords': (36.48327155579628, 127.71821043397682)},
#  {'name': '의료법인정산의료재단효성병원', 'coords': (36.62455637262831, 127.49558522201268)},
#  {'name': '의료법인정안의료재단중앙병원', 'coords': (35.53208761614168, 129.3048401436768)},
#  {'name': '의료법인정화의료재단 봉생기념병원',
#   'coords': (35.13085783627095, 129.0505708823645)},
#  {'name': '의료법인조윤의료재단영동병원', 'coords': (36.1852328446, 127.7808325647)},
#  {'name': '의료법인창녕서울의료재단창녕서울병원',
#   'coords': (35.53476250295272, 128.4976162683357)},
#  {'name': '의료법인청구성심병원', 'coords': (37.62079154435882, 126.91955399169244)},
#  {'name': '의료법인청아의료재단청아병원', 'coords': (35.24798366104159, 128.50971731844322)},
#  {'name': '의료법인청파의료재단송탄중앙병원', 'coords': (37.0885408447458, 127.0641653404409)},
#  {'name': '의료법인칠석의료재단사랑의병원',
#   'coords': (37.327020396286656, 126.84486352776976)},
#  {'name': '의료법인태성의료재단제일조은병원',
#   'coords': (36.99760379156879, 127.59853452216106)},
#  {'name': '의료법인토마스의료재단윌스기념병원',
#   'coords': (37.26502978126203, 127.0254583588438)},
#  {'name': '의료법인풍산의료재단동부제일병원',
#   'coords': (37.60067564592665, 127.1090292210168)},
#  {'name': '의료법인플러스의료재단단원병원', 'coords': (37.3002188172703, 126.81357021652911)},
#  {'name': '의료법인한국의료재단한국병원',
#   'coords': (34.947741459842966, 127.51235838977138)},
#  {'name': '의료법인한마음의료재단 여수제일병원',
#   'coords': (34.766166666666656, 127.66355833333331)},
#  {'name': '의료법인한마음의료재단하나병원',
#   'coords': (36.623474045244464, 127.43081864239412)},
#  {'name': '의료법인한전의료재단 한일병원',
#   'coords': (37.64611570419094, 127.02902417950423)},
#  {'name': '의료법인합포의료재단에스엠지연세병원',
#   'coords': (35.18635329986849, 128.56163160027907)},
#  {'name': '의료법인해민의료재단 세안종합병원',
#   'coords': (34.817030098221025, 126.38033941552499)},
#  {'name': '의료법인행복나눔의료재단장성병원',
#   'coords': (35.305871659607845, 126.78361958777766)},
#  {'name': '의료법인행촌의료재단 해남종합병원',
#   'coords': (34.571547222222215, 126.61268333333332)},
#  {'name': '의료법인환명의료재단조은금강병원', 'coords': (35.2623038386, 128.8615781975)},
#  {'name': '의료법인힐링의료재단옥천성모병원',
#   'coords': (36.313345842294304, 127.57197742757523)},
#  {'name': '의산의료재단강릉고려병원', 'coords': (37.75910092005996, 128.89982468955142)},
#  {'name': '이화여자대학교의과대학부속목동병원',
#   'coords': (37.53654282637804, 126.8862159683056)},
#  {'name': '이화여자대학교의과대학부속서울병원', 'coords': (37.557261149, 126.8362659275)},
#  {'name': '인산의료재단메트로병원', 'coords': (37.378597979767605, 126.93529986382784)},
#  {'name': '인성병원', 'coords': (37.88124367430593, 127.7268803699377)},
#  {'name': '인제대학교 해운대백병원', 'coords': (35.17334313589264, 129.182181239924)},
#  {'name': '인제대학교부산백병원', 'coords': (35.146454469689104, 129.02057150748323)},
#  {'name': '인제대학교상계백병원', 'coords': (37.6485812672986, 127.06311619032103)},
#  {'name': '인제대학교일산백병원', 'coords': (37.67436543525074, 126.75031388046008)},
#  {'name': '인천광역시의료원', 'coords': (37.47884441174466, 126.66861045817642)},
#  {'name': '인천광역시의료원백령병원', 'coords': (37.96801574541532, 124.72111307252132)},
#  {'name': '인천기독병원', 'coords': (37.47122873588076, 126.63208102847187)},
#  {'name': '인천더드림병원', 'coords': (37.53499881280362, 126.72225367019578)},
#  {'name': '인천사랑병원', 'coords': (37.4620681991805, 126.680345104401)},
#  {'name': '인천세종병원', 'coords': (37.5325382832, 126.7368531237)},
#  {'name': '인천적십자병원', 'coords': (37.4185669257, 126.6875335314)},
#  {'name': '인천힘찬종합병원', 'coords': (37.4010623210136, 126.714686842521)},
#  {'name': '인하대학교의과대학부속병원', 'coords': (37.4584235016321, 126.631868269228)},
#  {'name': '임실군보건의료원', 'coords': (35.61249558187053, 127.28697578028248)},
#  {'name': '장수군보건의료원', 'coords': (35.654664903392614, 127.52014287444382)},
#  {'name': '장흥우리병원', 'coords': (34.67838230801459, 126.91109914454888)},
#  {'name': '재단법인 베스티안재단 베스티안부산병원',
#   'coords': (35.235586741528486, 129.00862669149657)},
#  {'name': '재단법인베스티안재단베스티안병원', 'coords': (36.6364279047, 127.3216412104)},
#  {'name': '재단법인베스티안재단베스티안서울병원',
#   'coords': (37.5651102845783, 127.028019796271)},
#  {'name': '재단법인아산사회복지재단 서울아산병원',
#   'coords': (37.526563966361216, 127.10823825113609)},
#  {'name': '재단법인아산사회복지재단보령아산병원',
#   'coords': (36.38113998244595, 126.62282846665184)},
#  {'name': '재단법인아산사회복지재단정읍아산병원',
#   'coords': (35.58899495218047, 126.82346011194952)},
#  {'name': '재단법인예수병원유지재단예수병원',
#   'coords': (35.81440117465108, 127.13325187439274)},
#  {'name': '재단법인일신기독교선교회 일신기독병원',
#  {'name': '충청남도공주의료원', 'coords': (36.45905455773722, 127.10921562289596)},
#  {'name': '충청남도서산의료원', 'coords': (36.77556877677842, 126.46515725738563)},
#  {'name': '충청남도천안의료원', 'coords': (36.775359921186194, 127.17992025598448)},
#  {'name': '충청남도홍성의료원', 'coords': (36.59933992060475, 126.67440672396911)},
#  {'name': '충청북도 청주의료원', 'coords': (36.6401389722304, 127.473087555201)},
#  {'name': '충청북도충주의료원', 'coords': (36.97956732195825, 127.9703586011334)},
#  {'name': '칠곡경북대학교병원', 'coords': (35.9560830613237, 128.564408469835)},
#  {'name': '큐병원', 'coords': (35.10658381193713, 128.96489218029475)},
#  {'name': '태안군보건의료원', 'coords': (36.75191402131483, 126.32320735565844)},
#  {'name': '태황의료재단한성병원', 'coords': (35.5421522771, 128.4934147264)},
#  {'name': '파주한빛병원', 'coords': (37.77395345418349, 126.72122440556852)},
#  {'name': '평창군보건의료원', 'coords': (37.360577433652736, 128.3890508672411)},
#  {'name': '포항성모병원', 'coords': (36.01585627687779, 129.33981334567275)},
#  {'name': '포항세명기독병원', 'coords': (36.0181008246, 129.3615706051)},
#  {'name': '하나병원', 'coords': (35.0822158154719, 128.086480599028)},
#  {'name': '하남성심병원', 'coords': (35.1664063968, 126.800894228816)},
#  {'name': '하늘정형외과의원', 'coords': (37.48951057425082, 126.5632024449348)},
#  {'name': '하동중앙의원', 'coords': (35.07144347237017, 127.75322730361015)},
#  {'name': '학교법인 고려중앙학원 고려대학교의과대학부속병원(안암병원)',
#   'coords': (37.58715608002366, 127.02647086385966)},
#  {'name': '학교법인 춘해병원', 'coords': (35.147036979509224, 129.05854773411613)},
#  {'name': '학교법인)동의병원', 'coords': (35.169922174960384, 129.0767443760438)},
#  {'name': '학교법인가톨릭학원가톨릭대학교대전성모병원',
#   'coords': (36.32302490017959, 127.42027313317438)},
#  {'name': '학교법인가톨릭학원가톨릭대학교서울성모병원',
#   'coords': (37.50180080478528, 127.00472725970135)},
#  {'name': '학교법인건양교육재단건양대학교병원',
#   'coords': (36.306711701457246, 127.34263046359918)},
#  {'name': '학교법인건양교육재단건양대학교부여병원',
#   'coords': (36.27555409443824, 126.90169662482884)},
#  {'name': '학교법인동은학원순천향대학교부속천안병원',
#   'coords': (36.8023584971179, 127.135666806479)},
#  {'name': '학교법인성균관대학삼성창원병원', 'coords': (35.242599227316994, 128.592430520838)},
#  {'name': '학교법인울산공업학원울산대학교병원', 'coords': (35.5200593154, 129.4288047478)},
#  {'name': '학교법인을지학원대전을지대학교병원',
#   'coords': (36.35506871267816, 127.38199955857137)},
#  {'name': '학교법인을지학원의정부을지대학교병원',
#   'coords': (37.7518290378344, 127.050695679688)},
#  {'name': '한강수병원', 'coords': (37.5224047841717, 126.890913736375)},
#  {'name': '한국보훈복지의료공단 부산보훈병원',
#   'coords': (35.15333436517864, 129.00656514354415)},
#  {'name': '한국보훈복지의료공단 인천보훈병원', 'coords': (37.4557028395, 126.6526043685)},
#  {'name': '한국보훈복지의료공단 중앙보훈병원',
#   'coords': (37.52822090089664, 127.14671886173552)},
#  {'name': '한국보훈복지의료공단대구보훈병원',
#   'coords': (35.80313747018647, 128.55164640976287)},
#  {'name': '한국원자력의학원원자력병원', 'coords': (37.62881598133036, 127.08269315796588)},
#  {'name': '한림대학교강남성심병원', 'coords': (37.4932492859, 126.9086725295)},
#  {'name': '한림대학교동탄성심병원', 'coords': (37.216650193541184, 127.08000809235828)},
#  {'name': '한림대학교성심병원', 'coords': (37.3916511961, 126.9619708207)},
#  {'name': '한림대학교춘천성심병원', 'coords': (37.88413581388737, 127.73989454269612)},
#  {'name': '한림대학교한강성심병원', 'coords': (37.52346674579277, 126.91033000120588)},
#  {'name': '한마음병원', 'coords': (33.4962612399279, 126.54622454609036)},
#  {'name': '한양대학교구리병원', 'coords': (37.6012760077, 127.13250756940002)},
#  {'name': '한양대학교병원', 'coords': (37.559944533564746, 127.04488284061982)},
#  {'name': '한일병원', 'coords': (35.16696519825003, 128.128547657113)},
#  {'name': '함양성심병원', 'coords': (35.52046827900683, 127.72924773802184)},
#  {'name': '해남우리종합병원', 'coords': (34.58423738321411, 126.64658297551144)},
#  {'name': '해피뷰병원', 'coords': (35.15846280570811, 126.9066923373126)},
#  {'name': '행복한병원', 'coords': (35.37461994215032, 128.7114865036199)},
#  {'name': '행복한병원', 'coords': (35.69330550768229, 128.47043956090056)},
#  {'name': '현대병원', 'coords': (37.715486551355895, 127.17984989970032)},
#  {'name': '현대병원', 'coords': (36.78311829920936, 127.00097027728452)},
#  {'name': '현대유비스병원', 'coords': (37.46174383349464, 126.64314168953122)},
#  {'name': '혜민병원', 'coords': (37.535315660180416, 127.08360130258502)},
#  {'name': '혜성병원', 'coords': (37.6501095660175, 127.238321935956)},
#  {'name': '홍익병원', 'coords': (37.52844147447355, 126.8636640030062)},
#  {'name': '홍천아산병원', 'coords': (37.69082165229579, 127.89490721695594)},
#  {'name': '화성디에스병원', 'coords': (37.19922971137399, 126.82571090454118)},
#  {'name': '화성유일병원', 'coords': (37.21778332253106, 126.83265357240964)},
#  {'name': '화순고려병원', 'coords': (35.05595373646754, 126.98963562835073)},
#  {'name': '화순성심병원', 'coords': (35.05844089636795, 126.98987847235264)},
#  {'name': '화순전남대학교병원', 'coords': (35.0586707410237, 127.002108292339)},
#  {'name': '화천군보건의료원', 'coords': (38.1073824571151, 127.708883438378)},
#  {'name': '횡성대성병원', 'coords': (37.47845901170136, 127.97994775890872)},
#  {'name': '효산의료재단안양샘병원', 'coords': (37.39340413136221, 126.92447734066778)},
#  {'name': '효산의료재단지샘병원', 'coords': (37.35864464913468, 126.94735972779895)},
#  {'name': '효성시티병원', 'coords': (35.18541271514478, 129.12145899191526)},
#  {'name': '흑룡의원', 'coords': (37.959524356, 124.6654985764)},
#  {'name': '희명병원', 'coords': (37.45567063464179, 126.90056251863876)}]

# %%
def recommend_hospitals(user_location, emergency_locations, API_KEY_ID, API_KEY, max_distance=10, max_attempt_distance=50):
    import requests
    from math import radians, sin, cos, sqrt, atan2
    # Haversine 함수
    def haversine(coord1, coord2):
        R = 6371.0  # 지구 반지름 (km)
        lat1, lon1 = radians(coord1[0]), radians(coord1[1])
        lat2, lon2 = radians(coord2[0]), radians(coord2[1])
        dlat = lat2 - lat1
        dlon = lon2 - lon1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        return R * c

    # Directions API 호출 함수
    def get_travel_time_with_fallback(start_coords, end_coords):
        url = "https://naveropenapi.apigw.ntruss.com/map-direction/v1/driving"
        options = ["trafast", "traoptimal"]  # 사용할 옵션 순서
        headers = {
            "X-NCP-APIGW-API-KEY-ID": API_KEY_ID,
            "X-NCP-APIGW-API-KEY": API_KEY
        }

        for option in options:
            params = {
                "start": f"{start_coords[1]},{start_coords[0]}",  # 경도, 위도 순서
                "goal": f"{end_coords[1]},{end_coords[0]}",
                "option": option
            }

            try:
                response = requests.get(url, headers=headers, params=params)
                response.raise_for_status()
                data = response.json()

                # 'route' 데이터 확인 및 처리
                if "route" in data and option in data["route"]:
                    summary = data["route"][option][0]["summary"]
                    duration_ms = summary["duration"]  # 소요 시간 (밀리초)
                    distance_m = summary["distance"]  # 도로 거리 (미터)
                    return duration_ms / 1000, distance_m / 1000  # 초 단위, km 단위 반환
            except requests.exceptions.RequestException as e:
                print(f"{option} 옵션 실패: {e}")
            except KeyError as e:
                print(f"API 응답에서 예상치 못한 데이터 구조: {e}")

        # 모든 옵션 실패 시
        return float("inf"), float("inf")

    # 거리 기준 확장하며 병원 검색
    current_distance = max_distance
    while current_distance <= max_attempt_distance:
        filtered_hospitals = [
            loc for loc in emergency_locations
            if haversine(user_location, loc["coords"]) <= current_distance
        ]

        if filtered_hospitals:
            results = []
            for hospital in filtered_hospitals:
                travel_time, road_distance = get_travel_time_with_fallback(user_location, hospital["coords"])
                if not (travel_time is None or travel_time == float("inf")):  # 유효한 값만 추가
                    results.append({
                        "name": hospital["name"],
                        "road_distance": road_distance,
                        "travel_time": travel_time
                    })

            if results:  # 유효한 결과가 있는 경우
                top_3_hospitals = sorted(results, key=lambda x: x["travel_time"])[:3]

                print("추천 병원:")
                for hospital in top_3_hospitals:
                    duration_in_seconds = hospital["travel_time"]  # 초 단위 값
                    hours = int(duration_in_seconds // 3600)
                    minutes = int((duration_in_seconds % 3600) // 60)
                    print(
                        f"- {hospital['name']}, 도로 거리: {hospital['road_distance']:.2f}km, "
                        f"예상 소요 시간: {hours}시간 {minutes}분"
                    )
                return  # 추천 병원 출력 후 종료
        current_distance += 10

    # 최대 거리까지 검색했지만 병원 없음
    print(f"{max_attempt_distance}km 내 유효한 병원을 찾을 수 없습니다.")

# %%
user_location = (37.5034138, 126.7660309)  # 사용자 좌표 예시
recommend_hospitals(user_location, emergency_locations, c_id, c_key)
# Out:
# 추천 병원:
# - 순천향대학교부속부천병원, 도로 거리: 1.28km, 예상 소요 시간: 0시간 5분
# - 의료법인대인의료재단다니엘종합병원, 도로 거리: 1.58km, 예상 소요 시간: 0시간 7분
# - 뉴대성병원, 도로 거리: 2.72km, 예상 소요 시간: 0시간 11분

# %% [markdown]
# ## **Mission Complete!**
#
# 수고 많았습니다!
