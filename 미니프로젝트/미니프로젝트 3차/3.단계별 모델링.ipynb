# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계3 : 단계별 모델링

# %% [markdown]
# ## 0.미션4

# %% [markdown]
# * 단계별로 나눠서 모델링을 수행하고자 합니다.
# * 단계 구분 예시
#     * 단계1 : 정적(0), 동적(1) 행동 분류 모델 생성
#     * 단계2 : 세부 동작에 대한 분류모델 생성
#         * 단계1 모델에서 0으로 예측 -> 정적 행동 3가지 분류 모델링
#         * 단계1 모델에서 1으로 예측 -> 동적 행동 3가지 분류 모델링
# * 모델 통합
#     * 두 단계 모델을 통합하고, 새로운 데이터에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
# * 성능 비교
#     * 기본 모델링의 성능과 비교
#     * 성능 가이드
#         * Accuracy : 0.97 ~ 0.99
# * 파이프라인 구성
#     * test 데이터를 입력하여, 전처리 및 예측결과가 나오도록 함수 구성

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project3/'

# %% [markdown]
# ### (2) 라이브러리 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import *

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.backend import clear_session
from keras.optimizers import Adam

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %% [markdown]
# #### 1) 데이터로딩

# %%
file1 = 'data01_train.csv'
file2 = 'data01_test.csv'
file3 = 'features.csv'

# %%
data = pd.read_csv(path + file1)
test = pd.read_csv(path + file2)
features = pd.read_csv(path + file3)

# %%
# 불필요한 칼럼 삭제
data.drop('subject', axis=1, inplace=True)
test.drop('subject', axis=1, inplace=True)

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
#전체 데이터의 행,열 개수 확인
data.shape
# Out:
# (5881, 562)

# %%
#전체 데이터의 상위 5개 행 확인
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.965650         -0.929747  ...                        -0.487737
# 1         -0.987558         -0.937337  ...                        -0.237820
# 2         -0.995017         -0.942584  ...                        -0.535287
# 3         -0.347916          0.008288  ...                        -0.004012
# 4         -0.346372          0.584131  ...                        -0.157832
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.816696                    -0.042494
# 1                        -0.693515                    -0.062899
# 2                        -0.829311                     0.000265
# 3                        -0.408956                    -0.255125
# 4                        -0.563437                    -0.044344
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                             -0.044218                          0.307873
# 1                              0.388459                         -0.765014
# 2                             -0.525022                         -0.891875
# 3                              0.612804                          0.747381
# 4                             -0.845268                         -0.974650
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.072790             -0.601120
# 1                              0.771524              0.345205
# 2                              0.021528             -0.833564
# 3                             -0.072944             -0.695819
# 4                             -0.887846             -0.705029
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)            Activity
# 0              0.331298              0.165163            STANDING
# 1             -0.769186             -0.147944              LAYING
# 2              0.202434             -0.032755            STANDING
# 3              0.287154              0.111388             WALKING
# 4              0.264952              0.137758  WALKING_DOWNSTAIRS
#
# [5 rows x 562 columns]

# %%
#전체 데이터의 수치형 변수 분포 확인
data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# 25%           -0.992774         -0.977680         -0.980127         -0.993602
# 50%           -0.943933         -0.844575         -0.856352         -0.948501
# 75%           -0.242130         -0.034499         -0.262690         -0.291138
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       5881.000000       5881.000000       5881.000000  ...
# mean          -0.525944         -0.605374         -0.465490  ...
# std            0.485115          0.413043          0.544995  ...
# min           -0.999419         -1.000000         -1.000000  ...
# 25%           -0.977865         -0.980112         -0.936067  ...
# 50%           -0.849266         -0.849896         -0.878729  ...
# 75%           -0.068857         -0.268539         -0.013690  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# count                      5881.000000                      5881.000000
# mean                          0.126955                        -0.305883
# std                           0.249176                         0.322808
# min                          -0.965725                        -0.979261
# 25%                          -0.021610                        -0.541969
# 50%                           0.133887                        -0.342923
# 75%                           0.288944                        -0.127371
# max                           0.946700                         0.989538
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      5881.000000                  5881.000000
# mean                         -0.623548                     0.008524
# std                           0.310371                     0.339730
# min                          -0.999765                    -0.976580
# 25%                          -0.845985                    -0.122361
# 50%                          -0.712677                     0.010278
# 75%                          -0.501158                     0.154985
# max                           0.956845                     1.000000
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           5881.000000                       5881.000000
# mean                              -0.001185                          0.009340
# std                                0.447197                          0.608190
# min                               -1.000000                         -1.000000
# 25%                               -0.294369                         -0.481718
# 50%                                0.005146                          0.011448
# 75%                                0.285030                          0.499857
# max                                1.000000                          0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           5881.000000           5881.000000
# mean                              -0.007099             -0.491501
# std                                0.476738              0.509069
# min                               -1.000000             -1.000000
# 25%                               -0.373345             -0.811397
# 50%                               -0.000847             -0.709441
# 75%                                0.356236             -0.511330
# max                                0.996078              0.977344
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)
# count           5881.000000           5881.000000
# mean               0.059299             -0.054594
# std                0.297340              0.278479
# min               -1.000000             -0.980143
# 25%               -0.018203             -0.141555
# 50%                0.182893              0.003951
# 75%                0.248435              0.111932
# max                0.478157              1.000000
#
# [8 rows x 561 columns]

# %%
#전체 데이터의 모든 변수 확인
data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-skewness()', 'fBodyBodyGyroJerkMag-kurtosis()',
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'Activity'],
#       dtype='object', length=562)

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# * 세부 요구사항
#     - Label 추가 : 1단계 모델을 위한 레이블 추가
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %% [markdown]
# ### (1) 1단계 모델링을 위한 레이블

# %%
print(data['Activity'].unique())
data['is_dynamic'] = np.where(data['Activity'].isin(['STANDING', 'LAYING','SITTING']), 0, 1)
# Out:
# ['STANDING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS' 'WALKING_UPSTAIRS'
#  'SITTING']

# %% [markdown]
# ### (2) x, y 분리

# %%
x = data.drop(['is_dynamic',  'Activity'], axis = 1)
y1 = data.loc[:, 'is_dynamic']
y2 = data.loc[:, 'Activity']

# %% [markdown]
# ### (3) 스케일링

# %% [markdown]
# * 세부 요구사항
#     - 스케일링을 필요로 하는 알고리즘 사용을 위해서 코드 수행
#     - min-max 방식 혹은 standard 방식 중 한가지 사용.

# %%
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %% [markdown]
# ### (4) 데이터 분할
# * train, val 분할

# %%
x_train, x_val, y1_train, y1_val = train_test_split(x, y1, test_size = .2, random_state = 100)
_, _, y2_train, y2_val = train_test_split(x, y2, test_size = .2, random_state = 100)

# %% [markdown]
# ## **3.단계별 모델링**

# %% [markdown]
# ### (1) 단계1

# %% [markdown]
# * 세부 요구사항
#     * 적절한 단계로 구분한 후, 1단계를 분류하는 모델 생성
#         * 예시 : 정적 행동(Laying, Sitting, Standing)과 동적 행동(동적 : Walking, Walking-Up, Walking-Down)을 구분하는 모델 생성.
#     * 몇 가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %% [markdown]
# #### 1) 모델1

# %%
n_features = x_train.shape[1]
n_features
# Out:
# 561

# %%
# 모델 설계
do_rate = 0.1

model1_1 = Sequential([Dense(512, input_shape = [n_features, ], activation = 'relu'),
                     Dense(256, activation = 'relu'),
                     Dense(128, activation = 'relu'),
                     Dense(64, activation = 'relu'),
                     Dense(32, activation = 'relu'),
                     Dense(1, activation = 'sigmoid')])
model1_1.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 512)                 │         287,744 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 462,337 (1.76 MB)
#  Trainable params: 462,337 (1.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
y1_train.shape, x_train.shape
# Out:
# ((4704,), (4704, 561))

# %%
# 컴파일 및 학습
model1_1.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy')
history = model1_1.fit(x_train, y1_train, epochs = 100, validation_split=0.2).history
# Out:
# Epoch 1/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0
100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3490e-09 - val_loss: 1.1833e-09
# Epoch 58/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1571e-10 - val_loss: 1.1329e-09
# Epoch 59/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7395e-09 - val_loss: 1.0811e-09
# Epoch 60/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2828e-09 - val_loss: 1.0394e-09
# Epoch 61/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.3125e-09 - val_loss: 9.9558e-10
# Epoch 62/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1283e-09 - val_loss: 9.5408e-10
# Epoch 63/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7580e-10 - val_loss: 9.3616e-10
# Epoch 64/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5082e-10 - val_loss: 8.7959e-10
# Epoch 65/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6971e-10 - val_loss: 8.4386e-10
# Epoch 66/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0131e-09 - val_loss: 8.0669e-10
# Epoch 67/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4366e-10 - val_loss: 7.7630e-10
# Epoch 68/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6214e-10 - val_loss: 7.3622e-10
# Epoch 69/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1289e-09 - val_loss: 7.2187e-10
# Epoch 70/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5098e-09 - val_loss: 6.9110e-10
# Epoch 71/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8155e-09 - val_loss: 6.6213e-10
# Epoch 72/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5947e-10 - val_loss: 6.3808e-10
# Epoch 73/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2846e-10 - val_loss: 6.1157e-10
# Epoch 74/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2459e-09 - val_loss: 5.8905e-10
# Epoch 75/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8815e-10 - val_loss: 5.6956e-10
# Epoch 76/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2654e-10 - val_loss: 5.4615e-10
# Epoch 77/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1597e-09 - val_loss: 5.2449e-10
# Epoch 78/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9424e-10 - val_loss: 5.0445e-10
# Epoch 79/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4245e-10 - val_loss: 4.8330e-10
# Epoch 80/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6248e-10 - val_loss: 4.6588e-10
# Epoch 81/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2750e-09 - val_loss: 4.4529e-10
# Epoch 82/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.2144e-10 - val_loss: 4.3037e-10
# Epoch 83/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9650e-10 - val_loss: 4.0962e-10
# Epoch 84/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4901e-10 - val_loss: 4.0520e-10
# Epoch 85/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1613e-10 - val_loss: 3.8262e-10
# Epoch 86/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2488e-10 - val_loss: 3.6540e-10
# Epoch 87/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7948e-10 - val_loss: 3.5312e-10
# Epoch 88/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2930e-10 - val_loss: 3.4072e-10
# Epoch 89/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9213e-10 - val_loss: 3.3533e-10
# Epoch 90/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1655e-10 - val_loss: 3.1691e-10
# Epoch 91/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1727e-10 - val_loss: 2.9906e-10
# Epoch 92/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5464e-10 - val_loss: 2.9471e-10
# Epoch 93/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4158e-10 - val_loss: 2.7435e-10
# Epoch 94/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3150e-10 - val_loss: 2.6767e-10
# Epoch 95/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9516e-10 - val_loss: 2.6080e-10
# Epoch 96/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7219e-10 - val_loss: 2.5043e-10
# Epoch 97/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.3953e-10 - val_loss: 2.4706e-10
# Epoch 98/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2499e-10 - val_loss: 2.3140e-10
# Epoch 99/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6967e-10 - val_loss: 2.2345e-10
# Epoch 100/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9898e-10 - val_loss: 2.1252e-10

# %%
dl_history_plot(history)

# %%
pred1_1 = model1_1.predict(x_val)
pred1_1 = np.where(pred1_1 > .5, 1, 0)
print('accuracy :',accuracy_score(y1_val, pred1_1))
print('='*60)
print(confusion_matrix(y1_val, pred1_1))
print('='*60)
print(classification_report(y1_val, pred1_1))
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# accuracy : 0.9991503823279524
# ============================================================
# [[664   1]
#  [  0 512]]
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       665
#            1       1.00      1.00      1.00       512
#
#     accuracy                           1.00      1177
#    macro avg       1.00      1.00      1.00      1177
# weighted avg       1.00      1.00      1.00      1177

# %% [markdown]
# #### 2) 모델2

# %%
# 모델 설계
do_rate = 0.2

model1_2 = Sequential([Dense(512, input_shape = [n_features, ], activation = 'relu'),
                     Dropout(do_rate),
                     Dense(256, activation = 'relu'),
                     Dropout(do_rate),
                     Dense
100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.0194e-07 - val_loss: 3.1957e-09
# Epoch 51/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.0632e-08 - val_loss: 3.1328e-09
# Epoch 52/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.8709e-08 - val_loss: 2.4525e-09
# Epoch 53/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5458e-08 - val_loss: 2.3516e-09
# Epoch 54/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5587e-07 - val_loss: 1.9865e-09
# Epoch 55/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8713e-07 - val_loss: 1.7044e-09
# Epoch 56/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4648e-07 - val_loss: 1.6421e-09
# Epoch 57/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6101e-08 - val_loss: 1.5385e-09
# Epoch 58/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.4781e-07 - val_loss: 1.3282e-09
# Epoch 59/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5979e-07 - val_loss: 1.2573e-09
# Epoch 60/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6976e-07 - val_loss: 1.2695e-09
# Epoch 61/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3096e-08 - val_loss: 1.2422e-09
# Epoch 62/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1884e-07 - val_loss: 1.0628e-09
# Epoch 63/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0450e-07 - val_loss: 9.6995e-10
# Epoch 64/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0571e-08 - val_loss: 9.2978e-10
# Epoch 65/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8894e-08 - val_loss: 8.6354e-10
# Epoch 66/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - val_loss: 2.6021e-04
# Epoch 67/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 5.3765e-15
# Epoch 68/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6316e-04 - val_loss: 3.0846e-17
# Epoch 69/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0131 - val_loss: 1.3144e-11
# Epoch 70/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0254e-07 - val_loss: 3.1454e-11
# Epoch 71/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9505e-06 - val_loss: 3.9119e-11
# Epoch 72/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2824e-07 - val_loss: 3.9343e-11
# Epoch 73/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1567e-08 - val_loss: 3.6727e-11
# Epoch 74/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9892e-04 - val_loss: 7.3024e-11
# Epoch 75/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2713e-07 - val_loss: 7.2944e-11
# Epoch 76/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0013 - val_loss: 8.1961e-11
# Epoch 77/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5261e-08 - val_loss: 7.7575e-11
# Epoch 78/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4647e-08 - val_loss: 7.3924e-11
# Epoch 79/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0208e-04 - val_loss: 5.7765e-08
# Epoch 80/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9837e-04 - val_loss: 9.8262e-07
# Epoch 81/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1350e-04 - val_loss: 1.5996e-05
# Epoch 82/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - val_loss: 1.9701e-06
# Epoch 83/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9629e-06 - val_loss: 4.0805e-08
# Epoch 84/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.2696e-07 - val_loss: 3.3563e-08
# Epoch 85/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.8694e-07 - val_loss: 1.9181e-08
# Epoch 86/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.6526e-07 - val_loss: 1.4279e-08
# Epoch 87/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.2137e-08 - val_loss: 1.2972e-08
# Epoch 88/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.8900e-09 - val_loss: 1.2906e-08
# Epoch 89/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.1668e-06 - val_loss: 1.4464e-10
# Epoch 90/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2657e-07 - val_loss: 7.2616e-11
# Epoch 91/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.5022e-08 - val_loss: 5.6425e-11
# Epoch 92/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1466e-11 - val_loss: 5.6212e-11
# Epoch 93/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3946e-09 - val_loss: 5.5651e-11
# Epoch 94/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.4146e-08 - val_loss: 4.7629e-11
# Epoch 95/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.8468e-09 - val_loss: 4.7430e-11
# Epoch 96/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.7810e-07 - val_loss: 3.6827e-11
# Epoch 97/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3260e-07 - val_loss: 3.3733e-11
# Epoch 98/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.9255e-08 - val_loss: 3.2634e-11
# Epoch 99/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7794e-08 - val_loss: 2.6853e-11
# Epoch 100/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8658e-07 - val_loss: 2.5620e-11

# %%
dl_history_plot(history)

# %%
pred1_2 = model1_2.predict(x_val)
pred1_2 = np.where(pred1_2 > .5, 1, 0)
print('accuracy :',accuracy_score(y1_val, pred1_2))
print('='*60)
print(confusion_matrix(y1_val, pred1_2))
print('='*60)
print(classification_report(y1_val, pred1_2))
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# accuracy : 0.9991503823279524
# ============================================================
# [[664   1]
#  [  0 512]]
# ============================================================
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       665
#            1       1.00      1.00      1.00       512
#
#     accuracy                           1.00      1177
#    macro avg       1.00      1.00      1.00      1177
# weighted avg       1.00      1.00      1.00      1177

# %% [markdown]
# ### (2) 단계2

# %% [markdown]
# #### 1) 단계2-1 : 정적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 정적 행동(Laying, Sitting, Standing)인 데이터 추출
#     * Laying, Sitting, Standing 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %%
x_train_0 = x_train[y1_train == 0]
y2_train_0 = y2_train[y1_train == 0]

x_val_0 = x_val[y1_val == 0]
y2_val_0 = y2_val[y1_val == 0]

# %%
int_encoder_0 = LabelEncoder()
y2_train_0 = y2_train_0.map({'LAYING':0, 'STANDING':1, 'SITTING':2})
y2_val_0 = y2_val_0.map({'LAYING':0, 'STANDING':1, 'SITTING':2})

# %%
# 모델 설계
do_rate = 0.1

model2_1 = Sequential([Dense(512, input_shape = [n_features, ], activation = 'relu'),
                     Dropout(do_rate),
                     Dense(512, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(256, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(256, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(128, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(128, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(64, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(64, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(32, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(32, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(3, activation = 'softmax')])
model2_1.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 512)                 │         287,744 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 812,579 (3.10 MB)
#  Trainable params: 812,579 (3.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 컴파일 및 학습
model2_1.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy')
history = model2_1.fit(x_train_0, y2_train_0, epochs = 100, validation_split=0.2).history
# Out:
# Epoch 1/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 19s 138ms/step - loss: 1.0977 - val_loss: 1.0590
# Epoch 2/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.0279 - val_loss: 0.8099
# Epoch 3/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8713 - val_loss: 0.5837
# Epoch 4/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6630 - val_loss: 0.2531
# Epoch 5/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3777 - val_loss: 0.1955
# Epoch 6/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3047 - val_loss: 0.1637
# Epoch 7/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2856 - val_loss: 0.1605
# Epoch 8/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2365 - val_loss: 0.1272
# Epoch 9/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2152 - val_loss: 0.1239
# Epoch 10/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1975 - val_loss: 0.1322
# Epoch 11/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1780 - val_loss: 0.1181
# Epoch 12/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1570 - val_loss: 0.1586
# Epoch 13/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1553 - val_loss: 0.1455
# Epoch 14/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1371 - val_loss: 0.1669
# Epoch 15/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1574 - val_loss: 0.1210
# Epoch 16/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1146 - val_loss: 0.1122
# Epoch 17/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1474 - val_loss: 0.1307
# Epoch 18/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1214 - val_loss: 0.1011
# Epoch 19/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1528 - val_loss: 0.1124
# Epoch 20/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1060 - val_loss: 0.1185
# Epoch 21/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1204 - val_loss: 0.1028
# Epoch 22/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1059 - val_loss: 0.1095
# Epoch 23/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0946 - val_loss: 0.1140
# Epoch 24/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0698 - val_loss: 0.1158
# Epoch 25/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0835 - val_loss: 0.1070
# Epoch 26/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0720 - val_loss: 0.1013
# Epoch 27/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0691 - val_loss: 0.1742
# Epoch 28/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1483 - val_loss: 0.1396
# Epoch 29/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0910 - val_loss: 0.1270
# Epoch 30/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0803 - val_loss: 0.1175
# Epoch 31/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0538 - val_loss: 0.1474
# Epoch 32/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0705 - val_loss: 0.1447
# Epoch 33/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0765 - val_loss: 0.1371
# Epoch 34/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0703 - val_loss: 0.1114
# Epoch 35/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0455 - val_loss: 0.1164
# Epoch 36/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0511 - val_loss: 0.1092
# Epoch 37/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0571 - val_loss: 0.1103
# Epoch 38/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0707 - val_loss: 0.1374
# Epoch 39/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0517 - val_loss: 0.1247
# Epoch 40/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0411 - val_loss: 0.1264
# Epoch 41/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0326 - val_loss: 0.1267
# Epoch 42/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - val_loss: 0.1203
# Epoch 43/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0418 - val_loss: 0.1654
# Epoch 44/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0434 - val_loss: 0.1451
# Epoch 45/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0293 - val_loss: 0.1302
# Epoch 46/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - val_loss: 0.1067
# Epoch 47/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0812 - val_loss: 0.1002
# Epoch 48/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0427 - val_loss: 0.1159
# Epoch 49/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0332 - val_loss: 0.1287
# Epoch 50/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0543 - val_loss: 0.1281
# Epoch 51/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0338 - val_loss: 0.1098
# Epoch 52/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0458 - val_loss: 0.1253
# Epoch 53/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - val_loss: 0.1318
# Epoch 54/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0221 - val_loss: 0.1378
# Epoch 55/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0212 - val_loss: 0.1432
# Epoch 56/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.1811
# Epoch 57/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0350 - val_loss: 0.1443
# Epoch 58/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0255 - val_loss: 0.1178
# Epoch 59/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0661 - val_loss: 0.1370
# Epoch 60/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0316 - val_loss: 0.1106
# Epoch 61/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0153 - val_loss: 0.1299
# Epoch 62/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0233 - val_loss: 0.1329
# Epoch 63/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0310 - val_loss: 0.1095
# Epoch 64/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - val_loss: 0.1321
# Epoch 65/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0116 - val_loss: 0.1501
# Epoch 66/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0209 - val_loss: 0.1604
# Epoch 67/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0173 - val_loss: 0.2288
# Epoch 68/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0364 - val_loss: 0.1161
# Epoch 69/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0215 - val_loss: 0.1444
# Epoch 70/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0476 - val_loss: 0.1195
# Epoch 71/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - val_loss: 0.1632
# Epoch 72/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - val_loss: 0.1497
# Epoch 73/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - val_loss: 0.1886
# Epoch 74/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0616 - val_loss: 0.1134
# Epoch 75/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0102 - val_loss: 0.1349
# Epoch 76/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0227 - val_loss: 0.1731
# Epoch 77/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - val_loss: 0.1603
# Epoch 78/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - val_loss: 0.1657
# Epoch 79/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - val_loss: 0.2360
# Epoch 80/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0278 - val_loss: 0.1341
# Epoch 81/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0214 - val_loss: 0.1379
# Epoch 82/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0226 - val_loss: 0.1207
# Epoch 83/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - val_loss: 0.1511
# Epoch 84/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0627 - val_loss: 0.1312
# Epoch 85/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0174 - val_loss: 0.1331
# Epoch 86/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - val_loss: 0.1450
# Epoch 87/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - val_loss: 0.1502
# Epoch 88/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.3212
# Epoch 89/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0425 - val_loss: 0.1274
# Epoch 90/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - val_loss: 0.1543
# Epoch 91/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0244 - val_loss: 0.1277
# Epoch 92/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - val_loss: 0.1709
# Epoch 93/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0312 - val_loss: 0.1566
# Epoch 94/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0137 - val_loss: 0.1582
# Epoch 95/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0127 - val_loss: 0.2190
# Epoch 96/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0167 - val_loss: 0.1747
# Epoch 97/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - val_loss: 0.2082
# Epoch 98/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0027 - val_loss: 0.1937
# Epoch 99/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097 - val_loss: 0.2455
# Epoch 100/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0130 - val_loss: 0.1613

# %%
# 학습곡선
dl_history_plot(history)

# %%
# 예측 및 평가
pred2_1 = model2_1.predict(x_val_0)
pred2_1 = np.argmax(pred2_1, axis = 1)

print('accuracy :',accuracy_score(y2_val_0, pred2_1))
print('='*60)
print(confusion_matrix(y2_val_0, pred2_1))
print('='*60)
print(classification_report(y2_val_0, pred2_1, target_names = ['LAYING', 'SITTING', 'STANDING']))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# accuracy : 0.9804511278195489
# ============================================================
# [[227   0   0]
#  [  0 213   6]
#  [  0   7 212]]
# ============================================================
#               precision    recall  f1-score   support
#
#       LAYING       1.00      1.00      1.00       227
#      SITTING       0.97      0.97      0.97       219
#     STANDING       0.97      0.97      0.97       219
#
#     accuracy                           0.98       665
#    macro avg       0.98      0.98      0.98       665
# weighted avg       0.98      0.98      0.98       665

# %% [markdown]
# #### 2) 단계2-2 : 동적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 동동적 행동(Walking, Walking Upstairs, Walking Downstairs)인 데이터 추출
#     * Walking, Walking Upstairs, Walking Downstairs 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %%
x_train_1 = x_train[y1_train == 1]
y2_train_1 = y2_train[y1_train == 1]

x_val_1 = x_val[y1_val == 1]
y2_val_1 = y2_val[y1_val == 1]

# %%
y2_train_1 = y2_train_1.map({'WALKING':0, 'WALKING_UPSTAIRS':1, 'WALKING_DOWNSTAIRS':2})
y2_val_1 = y2_val_1.map({'WALKING':0, 'WALKING_UPSTAIRS':1, 'WALKING_DOWNSTAIRS':2})

# %%
# 모델 설계
do_rate = 0.1

model2_2 = Sequential([Dense(512, input_shape = [n_features, ], activation = 'relu'),
                     Dropout(do_rate),
                     Dense(512, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(256, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(256, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(128, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(128, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(64, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(64, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(32, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(32, activation = 'relu'),
                     Dropout(do_rate),
                     Dense(3, activation = 'softmax')])
model2_2.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                     │ (None, 512)                 │         287,744 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_17 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_18 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_19 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 812,579 (3.10 MB)
#  Trainable params: 812,579 (3.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 컴파일 및 학습
model2_2.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy')
history = model2_2.fit(x_train_1, y2_train_1, epochs = 100, validation_split=0.2).history
# Out:
# Epoch 1/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 18s 185ms/step
100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2202e-04 - val_loss: 0.0032
# Epoch 81/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9809e-04 - val_loss: 0.0286
# Epoch 82/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0403 - val_loss: 0.0261
# Epoch 83/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 84/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 85/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - val_loss: 0.0135
# Epoch 86/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0355 - val_loss: 0.0856
# Epoch 87/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0416 - val_loss: 0.0361
# Epoch 88/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - val_loss: 0.0896
# Epoch 89/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0204 - val_loss: 0.0121
# Epoch 90/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - val_loss: 0.0011
# Epoch 91/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - val_loss: 0.0073
# Epoch 92/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - val_loss: 0.0088
# Epoch 93/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - val_loss: 0.0081
# Epoch 94/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0226 - val_loss: 9.6145e-04
# Epoch 95/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0181
# Epoch 96/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0199
# Epoch 97/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0226 - val_loss: 0.0018
# Epoch 98/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7681e-04 - val_loss: 0.0080
# Epoch 99/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7655e-04 - val_loss: 0.0111
# Epoch 100/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - val_loss: 2.2199e-04

# %%
# 학습곡선
dl_history_plot(history)

# %%
# 예측 및 평가
pred2_2 = model2_2.predict(x_val_1)
pred2_2 = np.argmax(pred2_2, axis = 1)

print('accuracy :',accuracy_score(y2_val_1, pred2_2))
print('='*60)
print(confusion_matrix(y2_val_1, pred2_2))
print('='*60)
print(classification_report(y2_val_1, pred2_2, target_names = ['WALKING','WALKING_UPSTAIRS','WALKING_DOWNSTAIRS']))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# accuracy : 0.9921875
# ============================================================
# [[197   0   1]
#  [  2 172   1]
#  [  0   0 139]]
# ============================================================
#                     precision    recall  f1-score   support
#
#            WALKING       0.99      0.99      0.99       198
#   WALKING_UPSTAIRS       1.00      0.98      0.99       175
# WALKING_DOWNSTAIRS       0.99      1.00      0.99       139
#
#           accuracy                           0.99       512
#          macro avg       0.99      0.99      0.99       512
#       weighted avg       0.99      0.99      0.99       512

# %% [markdown]
# ### (3) 분류 모델 파이프라인 구성

# %% [markdown]
# * 세부 요구사항
#     * 두 단계 모델을 통합하고, 새로운 데이터(test)에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
#     * 데이터 파이프라인 구축 : test데이터가 로딩되어 전처리 과정을 거치고, 예측 및 성능 평가 수행

# %% [markdown]
# * 예시
# ![](https://github.com/DA4BAM/image/blob/main/pipeline%20function.png?raw=true)

# %% [markdown]
# #### 1) 함수 만들기

# %%
def model_comb(model1, model2_1, model2_2, new_data, scaler):

    # 1. 전처리 -----------------------------------

    ## 1) 스케일링
    col_name = list(new_data)[:-1]
    new_data.loc[:,col_name] = scaler.transform(new_data.loc[:,col_name])

    ## 2) 입력값 만들기
    new_x = new_data.drop(['Activity'], axis = 1)


    # 2.예측 -----------------------------------

    ## 1) 단계1 모델로 0,1 구분
    pred1 = model1_1.predict(new_x)
    pred1 = np.where(pred1 > .5, 1, 0)

    new_data['pred1'] = pred1


    ## 2) 단계1의 결과로 데이터 나누기
    new_x_0 = new_data.loc[new_data['pred1'] == 0]
    new_x_1 = new_data.loc[new_data['pred1'] == 1]
    x_0 = new_x_0.drop(['Activity','pred1'], axis = 1)
    x_1 = new_x_1.drop(['Activity','pred1'], axis = 1)

    ## 3) 단계2 모델로 예측.
    pred2_1 = model2_1.predict(x_0)
    pred2_1 = pred2_1.argmax(axis = 1)
    pred2_2 = model2_2.predict(x_1)
    pred2_2 = pred2_2.argmax(axis = 1)

    ## 4) 예측 결과를 원래 값으로 변환
    new_x_0['pred2'] = pred2_1
    new_x_0['pred2'] = new_x_0['pred2'].map({0:'LAYING', 1:'STANDING', 2:'SITTING'})

    new_x_1['pred2'] = pred2_2
    new_x_1['pred2'] = new_x_1['pred2'].map({0:'WALKING', 1:'WALKING_UPSTAIRS', 2:'WALKING_DOWNSTAIRS'})

    ## 5) 하나로 합치기
    result = pd.concat([new_x_0, new_x_1], axis = 0)

    # 3.최종 성능평가 -----------------------------------
    print('accuracy :',accuracy_score(result['pred2'], result['Activity']))
    print('='*60)
    print(confusion_matrix(result['pred2'], result['Activity']))
    print('='*60)
    print(classification_report(result['pred2'], result['Activity']))

# %% [markdown]
# #### 2) test 셋으로 예측하고 평가하기

# %%
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.284379          -0.021981          -0.116683         -0.992490
# 1           0.277440          -0.028086          -0.118412         -0.996620
# 2           0.305833          -0.041023          -0.087303          0.006880
# 3           0.276053          -0.016487          -0.108381         -0.995379
# 4           0.271998           0.016904          -0.078856         -0.973468
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.979640         -0.963321         -0.992563         -0.977304
# 1         -0.927676         -0.972294         -0.997346         -0.931405
# 2          0.182800         -0.237984          0.005642          0.028616
# 3         -0.983978         -0.975854         -0.995877         -0.985280
# 4         -0.702462         -0.869450         -0.979810         -0.711601
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.958142         -0.938850  ...                        -0.509523
# 1         -0.971788         -0.939837  ...                        -0.210792
# 2         -0.236474          0.016311  ...                         0.579587
# 3         -0.974907         -0.941425  ...                        -0.566291
# 4         -0.856807         -0.920760  ...                         0.447577
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.850065                    -0.018043
# 1                        -0.613367                    -0.022456
# 2                         0.394388                    -0.362616
# 3                        -0.841455                     0.289548
# 4                         0.214219                     0.010111
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.092304                          0.074220
# 1                             -0.155414                          0.247498
# 2                              0.171069                          0.576349
# 3                              0.079801                         -0.020033
# 4                              0.114179                         -0.830776
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.714534             -0.671943
# 1                             -0.112257             -0.826816
# 2                             -0.688314             -0.743234
# 3                              0.291898             -0.639435
# 4                             -0.325098             -0.840817
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  Activity
# 0             -0.018351             -0.185733   SITTING
# 1              0.184489             -0.068699  STANDING
# 2              0.272186              0.053101   WALKING
# 3             -0.111998             -0.123298   SITTING
# 4              0.116237             -0.096615  STANDING
#
# [5 rows x 562 columns]

# %% [markdown]
# * 성능 평가

# %%
model_comb(model1_1, model2_1, model2_2, test, scaler)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# accuracy : 0.9836845683208701
# ============================================================
# [[292   1   0   0   0   0]
#  [  0 242   9   0   0   0]
#  [  0  11 278   0   0   0]
#  [  0   0   0 228   0   3]
#  [  0   0   0   0 195   0]
#  [  0   0   0   0   0 212]]
# ============================================================
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       293
#            SITTING       0.95      0.96      0.96       251
#           STANDING       0.97      0.96      0.97       289
#            WALKING       1.00      0.99      0.99       231
# WALKING_DOWNSTAIRS       1.00      1.00      1.00       195
#   WALKING_UPSTAIRS       0.99      1.00      0.99       212
#
#           accuracy                           0.98      1471
#          macro avg       0.98      0.98      0.98      1471
#       weighted avg       0.98      0.98      0.98      1471
# <ipython-input-42-ce42e29c17c1>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_x_0['pred2'] = pred2_1
# <ipython-input-42-ce42e29c17c1>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_x_0['pred2'] = new_x_0['pred2'].map({0:'LAYING', 1:'STANDING', 2:'SITTING'})
# <ipython-input-42-ce42e29c17c1>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_x_1['pred2'] = pred2_2
# <ipython-input-42-ce42e29c17c1>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_x_1['pred2'] = new_x_1['pred2'].map({0:'WALKING', 1:'WALKING_UPSTAIRS', 2:'WALKING_DOWNSTAIRS'})
