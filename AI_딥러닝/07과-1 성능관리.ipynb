# %% [markdown]
# # **성능관리**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### **(1) 라이브러리 로딩**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Flatten, Input
from keras.backend import clear_session
from keras.optimizers import Adam
from keras.datasets import mnist

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### **(2) 데이터로딩**

# %% [markdown]
# * 데이터 로딩
#     * 과적합을 위한 예제 데이터입니다.
#     * target
#     * feature : 0 ~ 299

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/overfit_sample.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    target      0      1      2      3      4      5      6      7      8  ...  \
# 0       1 -1.067 -1.114 -0.616  0.376  1.090  0.467 -0.422  0.460 -0.443  ...
# 1       0 -0.831  0.271  1.716  1.096  1.731 -0.197  1.904 -0.265  0.557  ...
# 2       0  0.099  1.390 -0.732 -1.065  0.005 -0.081 -1.450  0.317 -0.624  ...
# 3       1 -0.989 -0.916 -1.343  0.145  0.543  0.636  1.127  0.189 -0.118  ...
# 4       0  0.811 -1.509  0.522 -0.360 -0.220 -0.959  0.334 -0.566 -0.656  ...
#
#      290    291    292    293    294    295    296    297    298    299
# 0  0.220 -0.339  0.254 -0.179  0.352  0.125  0.347  0.436  0.958 -0.824
# 1 -0.765 -0.735 -1.158  2.554  0.856 -1.506  0.462 -0.029 -1.932 -0.343
# 2 -1.311  0.799 -1.001  1.544  0.575 -0.309 -0.339 -0.148 -0.646  0.725
# 3 -1.370  1.093  0.596 -0.589 -0.649 -0.163 -0.958 -1.081  0.805  3.401
# 4 -0.178  0.718 -1.017  1.249 -0.596 -0.445  1.751  1.442 -0.393 -0.643
#
# [5 rows x 301 columns]

# %%
data.shape
# Out:
# (250, 301)

# %% [markdown]
# ## **2. Early Stopping**

# %% [markdown]
# ### **(1) 데이터 준비**

# %%
# 데이터분할 : x, y
target = 'target'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# 데이터분할 : train, validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %%
# 스케일링
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### **(2) 모델링**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(3) 미리 멈춤!(Early Stopping)**

# %% [markdown]
# #### 1) 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### 2) 모델링 with early stopping

# %%
# 모델 선언
clear_session()

model2 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )
model2.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# EarlyStopping 설정 ------------
min_de = 0.001
pat = 4

es = EarlyStopping(monitor = 'val_loss', min_delta = min_de, patience = pat)
# --------------------------------

# 학습
hist = model2.fit(x_train, y_train, epochs = 100, validation_split=0.2,
                  callbacks = [es]).history
dl_history_plot(hist)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.6674 - val_loss: 0.5936
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5500 - val_loss: 0.5955
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5353 - val_loss: 0.5923
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5457 - val_loss: 0.5876
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5825 - val_loss: 0.5904
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5839 - val_loss: 0.5906
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5145 - val_loss: 0.5971
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5407 - val_loss: 0.5970

# %% [markdown]
# ## 3.Dropout

# %%
from keras.layers import Dropout

# %% [markdown]
# ### **(1) 적용 전**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) 적용 후**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model3 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dropout(0.4),
                      Dense(64, activation= 'relu'),
                      Dropout(0.4),
                      Dense(32, activation= 'relu'),
                      Dropout(0.4),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model3.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## 4.모델 저장하기

# %% [markdown]
# ### (1) 모델 저장하기
#
# * model.save(‘파일이름.keras’)
#     * 딥러닝 모델의 메소드로 .save가 제공됩니다.
#     * 파일이름.keras 파일이 저장됩니다.

# %%
model1.save('hanky.keras')
#/content/hanky.keras

# %% [markdown]
# * 저장된 파일은 왼쪽 '파일'탭에서 확인 가능
# * 파일을 다운로드 받을 수 있다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### (2) 모델 로딩하기
#
# * load_model 함수는 별도로 불러와야 합니다.
# * 경로를 맞춰주고 h5 파일을 읽어오면 그대로 사용 가능합니다.

# %%
from keras.models import load_model
model2 = load_model('hanky.keras')

# %% [markdown]
# * 불러온 모델 사용하기

# %%
pred2 = model2.predict(x_val)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step

# %%
pred2
# Out:
# array([[1.1665497e-04],
#        [1.8721608e-03],
#        [8.6510962e-01],
#        [7.5295866e-05],
#        [3.3525657e-03],
#        [8.1689256e-01],
#        [1.9603119e-04],
#        [6.9891510e-04],
#        [6.7964554e-02],
#        [9.4781530e-01],
#        [2.9486913e-02],
#        [2.0088071e-03],
#        [1.1714891e-04],
#        [3.4290639e-01],
#        [2.0085224e-04],
#        [4.3307524e-04],
#        [3.9222030e-04],
#        [6.2136207e-04],
#        [1.7504317e-04],
#        [3.9613606e-06],
#        [8.1446058e-01],
#        [7.6885730e-01],
#        [2.2474375e-02],
#        [1.3566046e-03],
#        [7.4718054e-03],
#        [4.0750510e-01],
#        [2.3684416e-03],
#        [4.2309961e-01],
#        [3.0516167e-05],
#        [8.2641945e-04],
#        [5.5352652e-01],
#        [1.6239414e-04],
#        [4.8331330e-03],
#        [1.3901954e-02],
#        [3.0296952e-03],
#        [6.4436538e-04],
#        [1.7771751e-04],
#        [1.8426286e-03],
#        [4.2393781e-02],
#        [1.6236021e-01],
#        [1.8219036e-03],
#        [5.6250727e-01],
#        [9.6104872e-01],
#        [2.0389790e-04],
#        [2.8962135e-01],
#        [8.8001609e-02],
#        [1.3518921e-04],
#        [6.9103530e-03],
#        [2.3335658e-03],
#        [2.8771550e-05]], dtype=float32)

# %%
pred2_1 = np.where(pred2> .5, 1, 0)

# %%
print(accuracy_score(y_val,pred2_1))
print('-'*60)
print(confusion_matrix(y_val, pred2_1))
print('-'*60)
print(classification_report(y_val, pred2_1))
# Out:
# 0.62
# ------------------------------------------------------------
# [[29  6]
#  [13  2]]
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.75        35
#            1       0.25      0.13      0.17        15
#
#     accuracy                           0.62        50
#    macro avg       0.47      0.48      0.46        50
# weighted avg       0.56      0.62      0.58        50

# %% [markdown]
# ### (3) 중간 체크포인트에 모델 저장하기

# %% [markdown]
# * 폴더 정리 : 위에서 저장한 파일들 제거하기

# %%
import os

def delete_h5_files(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".keras"):
            file_path = os.path.join(directory, filename)
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

# 삭제할 디렉토리 지정
directory_to_delete_from = "/content/"

# 확장자가 .h5인 파일 삭제
delete_h5_files(directory_to_delete_from)

# %% [markdown]
# #### 1) 체크포인트 함수 불러오기

# %%
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### 2) 모델링 체크포인트 저장

# %% [markdown]
# * 모델 선언

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(16, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.0001), loss='binary_crossentropy')

# %% [markdown]
# * 체크포인트 저장
#     * 아래 코드에서 ModelCheckpoint 콜백은 검증 데이터의 정확도(val_accuracy)를 기준으로 모델 저장
#     * 모델의 성능이 이전에 저장된 모델보다 향상될 때만 저장되도록 save_best_only=True로 설정
#     * 또한, verbose=1로 설정하면 모델이 저장될 때마다 콘솔에 메시지가 표시됨.

# %%
cp_path = '/content/{epoch:03d}.keras'  # Keras 2.11 이상 버전에서 모델 확장자 .keras
mcp = ModelCheckpoint(cp_path, monitor='val_loss', verbose = 1, save_best_only=True)

# 학습
hist = model1.fit(x_train, y_train, epochs = 50, validation_split=.2, callbacks=[mcp]).history
# Out:
# Epoch 1/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - loss: 0.8384
# Epoch 1: val_loss improved from inf to 0.76265, saving model to /content/001.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 590ms/step - loss: 0.8309 - val_loss: 0.7627
# Epoch 2/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.7592
# Epoch 2: val_loss improved from 0.76265 to 0.69178, saving model to /content/002.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.7461 - val_loss: 0.6918
# Epoch 3/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.6812
# Epoch 3: val_loss improved from 0.69178 to 0.64296, saving model to /content/003.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6743 - val_loss: 0.6430
# Epoch 4/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.6441
# Epoch 4: val_loss improved from 0.64296 to 0.61256, saving model to /content/004.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.6261 - val_loss: 0.6126
# Epoch 5/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.5955
# Epoch 5: val_loss improved from 0.61256 to 0.59692, saving model to /content/005.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5988 - val_loss: 0.5969
# Epoch 6/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.5835
# Epoch 6: val_loss improved from 0.59692 to 0.58945, saving model to /content/006.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5802 - val_loss: 0.5894
# Epoch 7/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.5402
# Epoch 7: val_loss improved from 0.58945 to 0.58677, saving model to /content/007.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5613 - val_loss: 0.5868
# Epoch 8/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.4975
# Epoch 8: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5343 - val_loss: 0.5878
# Epoch 9/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.5356
# Epoch 9: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5495 - val_loss: 0.5898
# Epoch 10/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.4297
# Epoch 10: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5189 - val_loss: 0.5907
# Epoch 11/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 0.6240
# Epoch 11: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5733 - val_loss: 0.5904
# Epoch 12/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.5877
# Epoch 12: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5796 - val_loss: 0.5896
# Epoch 13/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4508
# Epoch 13: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5341 - val_loss: 0.5893
# Epoch 14/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.5615
# Epoch 14: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5562 - val_loss: 0.5890
# Epoch 15/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4561
# Epoch 15: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5244 - val_loss: 0.5887
# Epoch 16/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.6415
# Epoch 16: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5693 - val_loss: 0.5890
# Epoch 17/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4733
# Epoch 17: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5105 - val_loss: 0.5898
# Epoch 18/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4722
# Epoch 18: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5518 - val_loss: 0.5906
# Epoch 19/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5631
# Epoch 19: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5487 - val_loss: 0.5910
# Epoch 20/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5792
# Epoch 20: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5497 - val_loss: 0.5908
# Epoch 21/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4861
# Epoch 21: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5127 - val_loss: 0.5913
# Epoch 22/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5714
# Epoch 22: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5500 - val_loss: 0.5918
# Epoch 23/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5108
# Epoch 23: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5402 - val_loss: 0.5925
# Epoch 24/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.6237
# Epoch 24: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5550 - val_loss: 0.5930
# Epoch 25/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4316
# Epoch 25: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5144 - val_loss: 0.5930
# Epoch 26/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5614
# Epoch 26: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5516 - val_loss: 0.5933
# Epoch 27/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6493
# Epoch 27: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5720 - val_loss: 0.5936
# Epoch 28/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5374
# Epoch 28: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5460 - val_loss: 0.5935
# Epoch 29/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5817
# Epoch 29: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5445 - val_loss: 0.5936
# Epoch 30/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.6390
# Epoch 30: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5700 - val_loss: 0.5938
# Epoch 31/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5631
# Epoch 31: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5373 - val_loss: 0.5941
# Epoch 32/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4431
# Epoch 32: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5124 - val_loss: 0.5943
# Epoch 33/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5193
# Epoch 33: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5437 - val_loss: 0.5947
# Epoch 34/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.6876
# Epoch 34: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5649 - val_loss: 0.5950
# Epoch 35/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4013
# Epoch 35: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5021 - val_loss: 0.5948
# Epoch 36/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4840
# Epoch 36: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5250 - val_loss: 0.5952
# Epoch 37/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4347
# Epoch 37: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4932 - val_loss: 0.5950
# Epoch 38/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4674
# Epoch 38: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4994 - val_loss: 0.5950
# Epoch 39/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.4865
# Epoch 39: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5195 - val_loss: 0.5959
# Epoch 40/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5176
# Epoch 40: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5164 - val_loss: 0.5960
# Epoch 41/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6048
# Epoch 41: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5406 - val_loss: 0.5962
# Epoch 42/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3687
# Epoch 42: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4906 - val_loss: 0.5958
# Epoch 43/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4911
# Epoch 43: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5188 - val_loss: 0.5959
# Epoch 44/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5685
# Epoch 44: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5226 - val_loss: 0.5959
# Epoch 45/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5855
# Epoch 45: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5342 - val_loss: 0.5959
# Epoch 46/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4387
# Epoch 46: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5018 - val_loss: 0.5962
# Epoch 47/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5208
# Epoch 47: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5060 - val_loss: 0.5964
# Epoch 48/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5236
# Epoch 48: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5161 - val_loss: 0.5966
# Epoch 49/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5060
# Epoch 49: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5235 - val_loss: 0.5969
# Epoch 50/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4675
# Epoch 50: val_loss did not improve from 0.58677
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5070 - val_loss: 0.5968

# %%
# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## **5.[참조]가중치 규제(Regularization)**

# %%
# 규제를 위해 필요한 함수 불러오기
from keras.regularizers import l1, l2

# %% [markdown]
# ### **(1) L1 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model4 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model4.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model4.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) L2 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model5 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model5.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model5.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)
