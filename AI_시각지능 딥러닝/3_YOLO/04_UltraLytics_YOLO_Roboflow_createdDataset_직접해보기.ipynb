# %% [markdown]
# # Roboflow에서 가져온 데이터셋 사용해보기

# %% [markdown]
# ## 1.데이터셋

# %% [markdown]
# * 데이터셋 라이브러리 설치하기

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %% [markdown]
# * 데이터셋 라이브러리 불러오기

# %%
from roboflow import Roboflow

# %% [markdown]
# * 데이터셋 설치하기

# %%
##############################################
## 사용자마다 API 키가 다릅니다!
rf = Roboflow(api_key="vOJCnFpStyQAaxJVYCrE")
##############################################
project = rf.workspace("mohamed-traore-2ekkp").project("face-detection-mik1i")
version = project.version(24)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Face-Detection-24 in yolov11:: 100%|██████████| 7643/7643 [00:00<00:00, 8149.99it/s]

# %% [markdown]
# ## 2.모델링

# %% [markdown]
# * 모델링 라이브러리 설치하기

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.5/877.5 kB 23.3 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['WANDB_MODE'] = 'disabled'

# %% [markdown]
# * 모델링 라이브러리 불러오기

# %%
from ultralytics import YOLO, settings
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# * 데이터셋 경로 수정 & YAML 파일 경로 수정

# %%
settings
# Out:
# {'settings_version': '0.0.6',
#  'datasets_dir': '/content/datasets',
#  'weights_dir': 'weights',
#  'runs_dir': 'runs',
#  'uuid': '569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': True,
#  'vscode_msg': True}

# %%
settings['datasets_dir'] = '/content/'
settings
# Out:
# {'settings_version': '0.0.6',
#  'datasets_dir': '/content/',
#  'weights_dir': 'weights',
#  'runs_dir': 'runs',
#  'uuid': '569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': True,
#  'vscode_msg': True}

# %%
import yaml

# %%
## yaml 파일 읽고 수정 필요

# %% [markdown]
# ### 3) 모델 구조에 사전 학습 가중치도 가져와서 사용해보기

# %% [markdown]
# * 모델 구조 및 사전 학습 가중치 선택하기

# %%
model = YOLO(model='yolo11n.pt', task='detect')
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 111MB/s]

# %% [markdown]
# * 모델 학습하기

# %%
model.train(model='/content/yolo11n.pt',
            ############################
            ## yaml 파일을 넣어주세요!!!!!!
            ## 이 데이터셋은 yaml의 val: 수정 필요!
            data='/content/Face-Detection-24/data.yaml',
            ############################
            epochs=1,
            )
# Out:
# Ultralytics 8.3.22 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# * 예측해보기

# %%
## 혹시나 에러나는 경우 해당 셀을 실행하고서 다시 진행해보세요.
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
results = model.predict(source='/content/drive/MyDrive/DataInsight_강의/2024_KT_AIVLE_6기/AI_시각지능/20241025_132629.jpg',
                        conf=0.5,    # 기본값이 0.25
                        iou=0.5,     # 기본값이 0.7
                        save=True,
                        line_width=2
                        )
# Out:
# image 1/1 /content/drive/MyDrive/DataInsight_강의/2024_KT_AIVLE_6기/AI_시각지능/20241025_132629.jpg: 640x480 1 face, 44.6ms
# Speed: 2.8ms preprocess, 44.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/train22
