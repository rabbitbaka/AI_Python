# %%
# !pip install roboflow
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="vOJCnFpStyQAaxJVYCrE")
project = rf.workspace("roboflowex").project("0814_test")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in 0814_test-4 to yolov11:: 100%|██████████| 8446/8446 [00:00<00:00, 23962.05it/s]
# Extracting Dataset Version Zip to 0814_test-4 in yolov11:: 100%|██████████| 203/203 [00:00<00:00, 2574.13it/s]
