# %%
import torch
x_train = torch.FloatTensor([[1,1],[2,2],[3,3]])
y_train = torch.FloatTensor([[10],[20],[30]])
W = torch.randn([2,1], requires_grad=True)
b = torch.randn(1, requires_grad=True)
optimizer = torch.optim.SGD([W,b], lr=0.01)

# [딥러닝 1단계] 모델을 만든다. Model Setup
def H(x):
  model = torch.matmul(x,W) +b
  return model

# [딥러닝 2단계] 학습을 시킨다. Training - W,b찾기
for i in range(2000):
  cost = torch.mean((H(x_train)-y_train)**2)
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
  if i%100 == 0: print('[Iteration]',i,'[Cost]',cost.detach().item())
# [딥러닝 3단계] 추론을 수행한다. Inference
x_test = torch.FloatTensor([4,4])
model_result = H(x_test)
print('Model Inference with [4,4]:')
print(model_result.detach())
print(model_result.detach().item())
# Out:
# [Iteration] 0 [Cost] 522.6552124023438
# [Iteration] 100 [Cost] 0.08770626783370972
# [Iteration] 200 [Cost] 0.05196421220898628
# [Iteration] 300 [Cost] 0.030788153409957886
# [Iteration] 400 [Cost] 0.018241608515381813
# [Iteration] 500 [Cost] 0.010807965882122517
# [Iteration] 600 [Cost] 0.00640360452234745
# [Iteration] 700 [Cost] 0.0037940635811537504
# [Iteration] 800 [Cost] 0.0022480038460344076
# [Iteration] 900 [Cost] 0.00133185600861907
# [Iteration] 1000 [Cost] 0.0007890979177318513
# [Iteration] 1100 [Cost] 0.00046753938659094274
# [Iteration] 1200 [Cost] 0.0002770654682535678
# [Iteration] 1300 [Cost] 0.0001641608978388831
# [Iteration] 1400 [Cost] 9.728432632982731e-05
# [Iteration] 1500 [Cost] 5.76359307160601e-05
# [Iteration] 1600 [Cost] 3.4165175748057663e-05
# [Iteration] 1700 [Cost] 2.0243995095370337e-05
# [Iteration] 1800 [Cost] 1.2004217751382384e-05
# [Iteration] 1900 [Cost] 7.118206212908262e-06
# Model Inference with [4,4]:
# tensor([39.9960])
# 39.99598693847656

# %%
import torch
x_train = torch.FloatTensor([[1,2],[2,3],[3,4],[4,4],[5,3],[6,2]])
y_train = torch.FloatTensor([[0],[0],[0],[1],[1],[1]])
W = torch.randn([2,1], requires_grad=True)
b = torch.randn(1, requires_grad=True)
optimizer = torch.optim.SGD([W,b], lr=0.01)

# [딥러닝 1단계] 모델을 만든다. Model Setup
def H(x):
  model = torch.sigmoid(torch.matmul(x,W)+b)
  return model

# [딥러닝 2단계] 학습을 시킨다. Training - w,b찾기
for i in range(2000):
  cost = torch.mean((-1)*y_train*torch.log(H(x_train))+(-1)*(1-y_train)*torch.log(1-H(x_train)))
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
  if i%100 == 0: print('[Iteration]',i,'[Cost]',cost.detach().item())
# [딥러닝 3단계] 추론을 수행한다. Inference
x_test = torch.FloatTensor([7,1])
model_result = H(x_test)
print('Model Inference with [7,1]:')
print(model_result.detach())
if model_result.detach() < 0.5:
  print("F")
else : print("A+")
# Out:
# [Iteration] 0 [Cost] 1.984392762184143
# [Iteration] 100 [Cost] 0.7813749313354492
# [Iteration] 200 [Cost] 0.5368905663490295
# [Iteration] 300 [Cost] 0.4173213243484497
# [Iteration] 400 [Cost] 0.35122689604759216
# [Iteration] 500 [Cost] 0.3096264600753784
# [Iteration] 600 [Cost] 0.2807072699069977
# [Iteration] 700 [Cost] 0.2591197192668915
# [Iteration] 800 [Cost] 0.24215777218341827
# [Iteration] 900 [Cost] 0.22831754386425018
# [Iteration] 1000 [Cost] 0.21669764816761017
# [Iteration] 1100 [Cost] 0.20672409236431122
# [Iteration] 1200 [Cost] 0.1980125457048416
# [Iteration] 1300 [Cost] 0.19029539823532104
# [Iteration] 1400 [Cost] 0.18337996304035187
# [Iteration] 1500 [Cost] 0.17712320387363434
# [Iteration] 1600 [Cost] 0.17141669988632202
# [Iteration] 1700 [Cost] 0.166176438331604
# [Iteration] 1800 [Cost] 0.1613360047340393
# [Iteration] 1900 [Cost] 0.1568421572446823
# Model Inference with [7,1]:
# tensor([1.0000])
# A+
